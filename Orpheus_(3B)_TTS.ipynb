# %% [markdown]
# <a href="https://colab.research.google.com/github/cgshft/unsloth-tts-finetuning/blob/main/Orpheus_(3B)_TTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# **NEW** Unsloth now supports training the new **gpt-oss** model from OpenAI! You can start finetune gpt-oss for free with our **[Colab notebook](https://x.com/UnslothAI/status/1953896997867729075)**!
#
# Unsloth now supports Text-to-Speech (TTS) models. Read our [guide here](https://docs.unsloth.ai/basics/text-to-speech-tts-fine-tuning).
#
# Read our **[Gemma 3N Guide](https://docs.unsloth.ai/basics/gemma-3n-how-to-run-and-fine-tune)** and check out our new **[Dynamic 2.0](https://docs.unsloth.ai/basics/unsloth-dynamic-2.0-ggufs)** quants which outperforms other quantization methods!
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab notebooks! Otherwise use pip install unsloth
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1,<4.0.0" "huggingface_hub>=0.34.0" hf_transfer
    # !pip install --no-deps unsloth
# !pip install snac

# %% [markdown]
# ### Unsloth
#
# `FastModel` supports loading nearly any model now! This includes Vision and Text models!
#
# Thank you to [Etherl](https://huggingface.co/Etherll) for creating this notebook!

# %%
from unsloth import FastLanguageModel
import torch

fourbit_models = [
    # 4bit dynamic quants for superior accuracy and low memory use
    "unsloth/gemma-3-4b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-12b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-27b-it-unsloth-bnb-4bit",
    # Qwen3 new models
    "unsloth/Qwen3-4B-unsloth-bnb-4bit",
    "unsloth/Qwen3-8B-unsloth-bnb-4bit",
    # Other very popular models!
    "unsloth/Llama-3.1-8B",
    "unsloth/Llama-3.2-3B",
    "unsloth/Llama-3.3-70B",
    "unsloth/mistral-7b-instruct-v0.3",
    "unsloth/Phi-4",
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/orpheus-3b-0.1-ft",
    max_seq_length= 2048, # Choose any for long context!
    dtype = None, # Select None for auto detection
    load_in_4bit = False, # Select True for 4bit which reduces memory usage
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# ==((====))==  Unsloth 2025.8.8: Fast Llama patching. Transformers: 4.55.2.
#    \\   /|    NVIDIA A100-SXM4-40GB. Num GPUs = 1. Max memory: 39.557 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 8.0. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 64, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 64,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3837251848.py in <cell line: 0>()
#       1 model = FastLanguageModel.get_peft_model(
# ----> 2     model,
#       3     r = 64, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
#       4     target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
#       5                       "gate_proj", "up_proj", "down_proj",],
#
# NameError: name 'model' is not defined

# %% [markdown]
# Mount Google Drive

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Extract .wavs

# %%
# !mkdir /content/wavs
# !tar -xvzf /content/drive/MyDrive/Coding/TTS/wavs.tar.gz -C /content
# Out:
# Streaming output truncated to the last 5000 lines.
# wavs/common_voice_eo_18092949.wav
# wavs/common_voice_eo_17985744.wav
# wavs/common_voice_eo_20731551.wav
# wavs/common_voice_eo_20677382.wav
# wavs/common_voice_eo_17908199.wav
# wavs/common_voice_eo_19844002.wav
# wavs/common_voice_eo_20885801.wav
# wavs/common_voice_eo_20720086.wav
# wavs/common_voice_eo_17900346.wav
# wavs/common_voice_eo_21216690.wav
# wavs/common_voice_eo_19069674.wav
# wavs/common_voice_eo_20878233.wav
# wavs/common_voice_eo_20847868.wav
# wavs/common_voice_eo_17907325.wav
# wavs/common_voice_eo_21225983.wav
# wavs/common_voice_eo_20708159.wav
# wavs/common_voice_eo_19543659.wav
# wavs/common_voice_eo_20495843.wav
# wavs/common_voice_eo_19543664.wav
# wavs/common_voice_eo_20689897.wav
# wavs/common_voice_eo_17926437.wav
# wavs/common_voice_eo_20424971.wav
# wavs/common_voice_eo_21485266.wav
# wavs/common_voice_eo_18415456.wav
# wavs/common_voice_eo_20434329.wav
# wavs/common_voice_eo_20878246.wav
# wavs/common_voice_eo_19327691.wav
# wavs/common_voice_eo_21419139.wav
# wavs/common_voice_eo_20818122.wav
# wavs/common_voice_eo_18871336.wav
# wavs/common_voice_eo_20506999.wav
# wavs/common_voice_eo_19346462.wav
# wavs/common_voice_eo_21235815.wav
# wavs/common_voice_eo_18592120.wav
# wavs/common_voice_eo_17910151.wav
# wavs/common_voice_eo_20734097.wav
# wavs/common_voice_eo_19998356.wav
# wavs/common_voice_eo_19381983.wav
# wavs/common_voice_eo_20372899.wav
# wavs/common_voice_eo_20836813.wav
# wavs/common_voice_eo_19859918.wav
# wavs/common_voice_eo_19854460.wav
# wavs/common_voice_eo_19891340.wav
# wavs/common_voice_eo_17898607.wav
# wavs/common_voice_eo_19795716.wav
# wavs/common_voice_eo_20737745.wav
# wavs/common_voice_eo_20686850.wav
# wavs/common_voice_eo_20474610.wav
# wavs/common_voice_eo_20015923.wav
# wavs/common_voice_eo_20544264.wav
# wavs/common_voice_eo_21314999.wav
# wavs/common_voice_eo_20473866.wav
# wavs/common_voice_eo_20743648.wav
# wavs/common_voice_eo_19111471.wav
# wavs/common_voice_eo_21365114.wav
# wavs/common_voice_eo_17913527.wav
# wavs/common_voice_eo_20874133.wav
# wavs/common_voice_eo_20809519.wav
# wavs/common_voice_eo_21094077.wav
# wavs/common_voice_eo_19543178.wav
# wavs/common_voice_eo_19848173.wav
# wavs/common_voice_eo_19343144.wav
# wavs/common_voice_eo_18469950.wav
# wavs/common_voice_eo_19419942.wav
# wavs/common_voice_eo_18587971.wav
# wavs/common_voice_eo_18972293.wav
# wavs/common_voice_eo_20987850.wav
# wavs/common_voice_eo_18532308.wav
# wavs/common_voice_eo_17906778.wav
# wavs/common_voice_eo_17904795.wav
# wavs/common_voice_eo_19427311.wav
# wavs/common_voice_eo_19419332.wav
# wavs/common_voice_eo_21015235.wav
# wavs/common_voice_eo_20472498.wav
# wavs/common_voice_eo_17976197.wav
# wavs/common_voice_eo_20796531.wav
# wavs/common_voice_eo_18023492.wav
# wavs/common_voice_eo_20558738.wav
# wavs/common_voice_eo_17970846.wav
# wavs/common_voice_eo_17957397.wav
# wavs/common_voice_eo_18950761.wav
# wavs/common_voice_eo_19845108.wav
# wavs/common_voice_eo_18590658.wav
# wavs/common_voice_eo_19327702.wav
# wavs/common_voice_eo_21235649.wav
# wavs/common_voice_eo_18597480.wav
# wavs/common_voice_eo_20454130.wav
# wavs/common_voice_eo_20908232.wav
# wavs/common_voice_eo_18244231.wav
# wavs/common_voice_eo_19787518.wav
# wavs/common_voice_eo_20450222.wav
# wavs/common_voice_eo_19555352.wav
# wavs/common_voice_eo_20868786.wav
# wavs/common_voice_eo_19451750.wav
# wavs/common_voice_eo_21108491.wav
# wavs/common_voice_eo_17999496.wav
# wavs/common_voice_eo_20698518.wav
# wavs/common_voice_eo_21377489.wav
# wavs/common_voice_eo_20432609.wav
# wavs/common_voice_eo_19854435.wav
# wavs/common_voice_eo_21158659.wav
# wavs/common_voice_eo_20425103.wav
# wavs/common_voice_eo_19427407.wav
# wavs/common_voice_eo_19492982.wav
# wavs/common_voice_eo_19736409.wav
# wavs/common_voice_eo_19404853.wav
# wavs/common_voice_eo_20485717.wav
# wavs/common_voice_eo_20462237.wav
# wavs/common_voice_eo_19309016.wav
# wavs/common_voice_eo_17892971.wav
# wavs/common_voice_eo_18883708.wav
# wavs/common_voice_eo_20424087.wav
# wavs/common_voice_eo_20182196.wav
# wavs/common_voice_eo_17941822.wav
# wavs/common_voice_eo_20091903.wav
# wavs/common_voice_eo_18584165.wav
# wavs/common_voice_eo_18900416.wav
# wavs/common_voice_eo_21502480.wav
# wavs/common_voice_eo_21337692.wav
# wavs/common_voice_eo_18591768.wav
# wavs/common_voice_eo_20482989.wav
# wavs/common_voice_eo_21330036.wav
# wavs/common_voice_eo_21181433.wav
# wavs/common_voice_eo_20949982.wav
# wavs/common_voice_eo_17907958.wav
# wavs/common_voice_eo_20378539.wav
# wavs/common_voice_eo_20558571.wav
# wavs/common_voice_eo_19860719.wav
# wavs/common_voice_eo_20442610.wav
# wavs/common_voice_eo_20237459.wav
# wavs/common_voice_eo_18055019.wav
# wavs/common_voice_eo_20276048.wav
# wavs/common_voice_eo_19926554.wav
# wavs/common_voice_eo_18506983.wav
# wavs/common_voice_eo_19272164.wav
# wavs/common_voice_eo_17908613.wav
# wavs/common_voice_eo_17908009.wav
# wavs/common_voice_eo_19841707.wav
# wavs/common_voice_eo_20228772.wav
# wavs/common_voice_eo_21314959.wav
# wavs/common_voice_eo_19317374.wav
# wavs/common_voice_eo_20104716.wav
# wavs/common_voice_eo_18611134.wav
# wavs/common_voice_eo_18900365.wav
# wavs/common_voice_eo_20809430.wav
# wavs/common_voice_eo_18336531.wav
# wavs/common_voice_eo_19012181.wav
# wavs/common_voice_eo_18469841.wav
# wavs/common_voice_eo_17898969.wav
# wavs/common_voice_eo_20502002.wav
# wavs/common_voice_eo_20498954.wav
# wavs/common_voice_eo_19543233.wav
# wavs/common_voice_eo_20552677.wav
# wavs/common_voice_eo_20209329.wav
# wavs/common_voice_eo_17907670.wav
# wavs/common_voice_eo_19270375.wav
# wavs/common_voice_eo_17907286.wav
# wavs/common_voice_eo_20560937.wav
# wavs/common_voice_eo_20673234.wav
# wavs/common_voice_eo_20423302.wav
# wavs/common_voice_eo_19820702.wav
# wavs/common_voice_eo_20313215.wav
# wavs/common_voice_eo_19555066.wav
# wavs/common_voice_eo_20511899.wav
# wavs/common_voice_eo_18063376.wav
# wavs/common_voice_eo_20473827.wav
# wavs/common_voice_eo_18871638.wav
# wavs/common_voice_eo_20496758.wav
# wavs/common_voice_eo_20821347.wav
# wavs/common_voice_eo_20241855.wav
# wavs/common_voice_eo_17916473.wav
# wavs/common_voice_eo_19755559.wav
# wavs/common_voice_eo_18584724.wav
# wavs/common_voice_eo_20235087.wav
# wavs/common_voice_eo_18826829.wav
# wavs/common_voice_eo_21096653.wav
# wavs/common_voice_eo_20664029.wav
# wavs/common_voice_eo_20105659.wav
# wavs/common_voice_eo_19247430.wav
# wavs/common_voice_eo_20424306.wav
# wavs/common_voice_eo_19750661.wav
# wavs/common_voice_eo_20270373.wav
# wavs/common_voice_eo_19127969.wav
# wavs/common_voice_eo_19343846.wav
# wavs/common_voice_eo_19369122.wav
# wavs/common_voice_eo_20502086.wav
# wavs/common_voice_eo_17912016.wav
# wavs/common_voice_eo_19543211.wav
# wavs/common_voice_eo_19111462.wav
# wavs/common_voice_eo_20511982.wav
# wavs/common_voice_eo_20345764.wav
# wavs/common_voice_eo_21093268.wav
# wavs/common_voice_eo_17906594.wav
# wavs/common_voice_eo_21486515.wav
# wavs/common_voice_eo_17899547.wav
# wavs/common_voice_eo_20575046.wav
# wavs/common_voice_eo_21365169.wav
# wavs/common_voice_eo_19460032.wav
# wavs/common_voice_eo_19355633.wav
# wavs/common_voice_eo_20561141.wav
# wavs/common_voice_eo_20426984.wav
# wavs/common_voice_eo_19247123.wav
# wavs/common_voice_eo_20956098.wav
# wavs/common_voice_eo_18591736.wav
# wavs/common_voice_eo_20734868.wav
# wavs/common_voice_eo_19815318.wav
# wavs/common_voice_eo_19337000.wav
# wavs/common_voice_eo_19165178.wav
# wavs/common_voice_eo_19787565.wav
# wavs/common_voice_eo_19343139.wav
# wavs/common_voice_eo_18455429.wav
# wavs/common_voice_eo_20488128.wav
# wavs/common_voice_eo_17936947.wav
# wavs/common_voice_eo_20700926.wav
# wavs/common_voice_eo_20452646.wav
# wavs/common_voice_eo_20690451.wav
# wavs/common_voice_eo_20426993.wav
# wavs/common_voice_eo_19781709.wav
# wavs/common_voice_eo_20640322.wav
# wavs/common_voice_eo_21135990.wav
# wavs/common_voice_eo_19266286.wav
# wavs/common_voice_eo_19484437.wav
# wavs/common_voice_eo_20677383.wav
# wavs/common_voice_eo_19860393.wav
# wavs/common_voice_eo_20423161.wav
# wavs/common_voice_eo_19253591.wav
# wavs/common_voice_eo_20466646.wav
# wavs/common_voice_eo_18114223.wav
# wavs/common_voice_eo_20427598.wav
# wavs/common_voice_eo_20189226.wav
# wavs/common_voice_eo_17957299.wav
# wavs/common_voice_eo_19128001.wav
# wavs/common_voice_eo_21076460.wav
# wavs/common_voice_eo_17906915.wav
# wavs/common_voice_eo_20209394.wav
# wavs/common_voice_eo_18731705.wav
# wavs/common_voice_eo_21101561.wav
# wavs/common_voice_eo_17961177.wav
# wavs/common_voice_eo_18135295.wav
# wavs/common_voice_eo_20960342.wav
# wavs/common_voice_eo_19860153.wav
# wavs/common_voice_eo_17906669.wav
# wavs/common_voice_eo_20427754.wav
# wavs/common_voice_eo_20450027.wav
# wavs/common_voice_eo_18005634.wav
# wavs/common_voice_eo_19276612.wav
# wavs/common_voice_eo_19336915.wav
# wavs/common_voice_eo_17895752.wav
# wavs/common_voice_eo_19886614.wav
# wavs/common_voice_eo_20495828.wav
# wavs/common_voice_eo_19504457.wav
# wavs/common_voice_eo_21326277.wav
# wavs/common_voice_eo_21293379.wav
# wavs/common_voice_eo_18900480.wav
# wavs/common_voice_eo_19750217.wav
# wavs/common_voice_eo_19875619.wav
# wavs/common_voice_eo_19787516.wav
# wavs/common_voice_eo_19788200.wav
# wavs/common_voice_eo_17922178.wav
# wavs/common_voice_eo_20455874.wav
# wavs/common_voice_eo_21487469.wav
# wavs/common_voice_eo_21067109.wav
# wavs/common_voice_eo_21072933.wav
# wavs/common_voice_eo_20487899.wav
# wavs/common_voice_eo_20489609.wav
# wavs/common_voice_eo_20544166.wav
# wavs/common_voice_eo_18074639.wav
# wavs/common_voice_eo_20455850.wav
# wavs/common_voice_eo_19871648.wav
# wavs/common_voice_eo_21050933.wav
# wavs/common_voice_eo_20242006.wav
# wavs/common_voice_eo_19504472.wav
# wavs/common_voice_eo_19422434.wav
# wavs/common_voice_eo_19786383.wav
# wavs/common_voice_eo_20472390.wav
# wavs/common_voice_eo_20467246.wav
# wavs/common_voice_eo_19127771.wav
# wavs/common_voice_eo_17898774.wav
# wavs/common_voice_eo_21137644.wav
# wavs/common_voice_eo_20224029.wav
# wavs/common_voice_eo_18078720.wav
# wavs/common_voice_eo_20694616.wav
# wavs/common_voice_eo_19114072.wav
# wavs/common_voice_eo_20426995.wav
# wavs/common_voice_eo_19368241.wav
# wavs/common_voice_eo_19272095.wav
# wavs/common_voice_eo_19545375.wav
# wavs/common_voice_eo_18714168.wav
# wavs/common_voice_eo_20820181.wav
# wavs/common_voice_eo_19131798.wav
# wavs/common_voice_eo_20816644.wav
# wavs/common_voice_eo_20428639.wav
# wavs/common_voice_eo_20511997.wav
# wavs/common_voice_eo_18545378.wav
# wavs/common_voice_eo_19776690.wav
# wavs/common_voice_eo_18892847.wav
# wavs/common_voice_eo_17906811.wav
# wavs/common_voice_eo_20688312.wav
# wavs/common_voice_eo_17898605.wav
# wavs/common_voice_eo_19545601.wav
# wavs/common_voice_eo_19821000.wav
# wavs/common_voice_eo_20483509.wav
# wavs/common_voice_eo_17996774.wav
# wavs/common_voice_eo_19321785.wav
# wavs/common_voice_eo_20440070.wav
# wavs/common_voice_eo_17910084.wav
# wavs/common_voice_eo_18492358.wav
# wavs/common_voice_eo_18850535.wav
# wavs/common_voice_eo_19804648.wav
# wavs/common_voice_eo_18005613.wav
# wavs/common_voice_eo_19400955.wav
# wavs/common_voice_eo_19039429.wav
# wavs/common_voice_eo_20670026.wav
# wavs/common_voice_eo_18709893.wav
# wavs/common_voice_eo_20498029.wav
# wavs/common_voice_eo_19543677.wav
# wavs/common_voice_eo_20806304.wav
# wavs/common_voice_eo_21512739.wav
# wavs/common_voice_eo_20132319.wav
# wavs/common_voice_eo_20432525.wav
# wavs/common_voice_eo_19822495.wav
# wavs/common_voice_eo_21394863.wav
# wavs/common_voice_eo_18728075.wav
# wavs/common_voice_eo_20424992.wav
# wavs/common_voice_eo_20688499.wav
# wavs/common_voice_eo_20884555.wav
# wavs/common_voice_eo_20429038.wav
# wavs/common_voice_eo_18607477.wav
# wavs/common_voice_eo_17970858.wav
# wavs/common_voice_eo_19467820.wav
# wavs/common_voice_eo_19875775.wav
# wavs/common_voice_eo_20626524.wav
# wavs/common_voice_eo_18483470.wav
# wavs/common_voice_eo_20519058.wav
# wavs/common_voice_eo_20987713.wav
# wavs/common_voice_eo_20182200.wav
# wavs/common_voice_eo_20734234.wav
# wavs/common_voice_eo_18076139.wav
# wavs/common_voice_eo_19000668.wav
# wavs/common_voice_eo_20270213.wav
# wavs/common_voice_eo_17945191.wav
# wavs/common_voice_eo_19845099.wav
# wavs/common_voice_eo_19543225.wav
# wavs/common_voice_eo_17899250.wav
# wavs/common_voice_eo_17898484.wav
# wavs/common_voice_eo_17916641.wav
# wavs/common_voice_eo_20737645.wav
# wavs/common_voice_eo_21306008.wav
# wavs/common_voice_eo_20119102.wav
# wavs/common_voice_eo_21179377.wav
# wavs/common_voice_eo_17904347.wav
# wavs/common_voice_eo_18546632.wav
# wavs/common_voice_eo_18545006.wav
# wavs/common_voice_eo_19870798.wav
# wavs/common_voice_eo_17926290.wav
# wavs/common_voice_eo_19115316.wav
# wavs/common_voice_eo_19426542.wav
# wavs/common_voice_eo_19864224.wav
# wavs/common_voice_eo_21374345.wav
# wavs/common_voice_eo_17913510.wav
# wavs/common_voice_eo_17997047.wav
# wavs/common_voice_eo_20891503.wav
# wavs/common_voice_eo_21184674.wav
# wavs/common_voice_eo_20473699.wav
# wavs/common_voice_eo_20722361.wav
# wavs/common_voice_eo_18790344.wav
# wavs/common_voice_eo_19427574.wav
# wavs/common_voice_eo_20873125.wav
# wavs/common_voice_eo_19114096.wav
# wavs/common_voice_eo_20877733.wav
# wavs/common_voice_eo_21377201.wav
# wavs/common_voice_eo_19122869.wav
# wavs/common_voice_eo_20488119.wav
# wavs/common_voice_eo_19859916.wav
# wavs/common_voice_eo_20886489.wav
# wavs/common_voice_eo_19802150.wav
# wavs/common_voice_eo_19321837.wav
# wavs/common_voice_eo_19856354.wav
# wavs/common_voice_eo_19355521.wav
# wavs/common_voice_eo_20722629.wav
# wavs/common_voice_eo_20930106.wav
# wavs/common_voice_eo_18592454.wav
# wavs/common_voice_eo_21419816.wav
# wavs/common_voice_eo_19773001.wav
# wavs/common_voice_eo_20426959.wav
# wavs/common_voice_eo_19347237.wav
# wavs/common_voice_eo_20489860.wav
# wavs/common_voice_eo_20474148.wav
# wavs/common_voice_eo_21261738.wav
# wavs/common_voice_eo_21217256.wav
# wavs/common_voice_eo_18236234.wav
# wavs/common_voice_eo_21431631.wav
# wavs/common_voice_eo_20719589.wav
# wavs/common_voice_eo_17957387.wav
# wavs/common_voice_eo_20733741.wav
# wavs/common_voice_eo_20472499.wav
# wavs/common_voice_eo_20483008.wav
# wavs/common_voice_eo_18727996.wav
# wavs/common_voice_eo_19382119.wav
# wavs/common_voice_eo_19501667.wav
# wavs/common_voice_eo_19622989.wav
# wavs/common_voice_eo_20453758.wav
# wavs/common_voice_eo_20212167.wav
# wavs/common_voice_eo_20690445.wav
# wavs/common_voice_eo_18089935.wav
# wavs/common_voice_eo_21085134.wav
# wavs/common_voice_eo_19382087.wav
# wavs/common_voice_eo_19782126.wav
# wavs/common_voice_eo_20753716.wav
# wavs/common_voice_eo_19776612.wav
# wavs/common_voice_eo_20968106.wav
# wavs/common_voice_eo_19127359.wav
# wavs/common_voice_eo_20993959.wav
# wavs/common_voice_eo_19412641.wav
# wavs/common_voice_eo_19864761.wav
# wavs/common_voice_eo_20878234.wav
# wavs/common_voice_eo_19755432.wav
# wavs/common_voice_eo_19039428.wav
# wavs/common_voice_eo_20905043.wav
# wavs/common_voice_eo_20884528.wav
# wavs/common_voice_eo_20688061.wav
# wavs/common_voice_eo_20216692.wav
# wavs/common_voice_eo_21138205.wav
# wavs/common_voice_eo_17909865.wav
# wavs/common_voice_eo_19381967.wav
# wavs/common_voice_eo_20925726.wav
# wavs/common_voice_eo_20451325.wav
# wavs/common_voice_eo_19478287.wav
# wavs/common_voice_eo_18729895.wav
# wavs/common_voice_eo_20664689.wav
# wavs/common_voice_eo_21076117.wav
# wavs/common_voice_eo_19867823.wav
# wavs/common_voice_eo_19841634.wav
# wavs/common_voice_eo_21184645.wav
# wavs/common_voice_eo_17960979.wav
# wavs/common_voice_eo_21146171.wav
# wavs/common_voice_eo_21259965.wav
# wavs/common_voice_eo_20717187.wav
# wavs/common_voice_eo_18896118.wav
# wavs/common_voice_eo_21085210.wav
# wavs/common_voice_eo_19668435.wav
# wavs/common_voice_eo_17907083.wav
# wavs/common_voice_eo_20822967.wav
# wavs/common_voice_eo_20442296.wav
# wavs/common_voice_eo_17892987.wav
# wavs/common_voice_eo_19876330.wav
# wavs/common_voice_eo_17903438.wav
# wavs/common_voice_eo_18597457.wav
# wavs/common_voice_eo_19253043.wav
# wavs/common_voice_eo_17936955.wav
# wavs/common_voice_eo_20532174.wav
# wavs/common_voice_eo_20499426.wav
# wavs/common_voice_eo_21279365.wav
# wavs/common_voice_eo_18593376.wav
# wavs/common_voice_eo_18828130.wav
# wavs/common_voice_eo_20093373.wav
# wavs/common_voice_eo_20495827.wav
# wavs/common_voice_eo_20345409.wav
# wavs/common_voice_eo_20228810.wav
# wavs/common_voice_eo_21297581.wav
# wavs/common_voice_eo_20617151.wav
# wavs/common_voice_eo_20222693.wav
# wavs/common_voice_eo_18866325.wav
# wavs/common_voice_eo_17911929.wav
# wavs/common_voice_eo_19311981.wav
# wavs/common_voice_eo_19793289.wav
# wavs/common_voice_eo_20960320.wav
# wavs/common_voice_eo_20201542.wav
# wavs/common_voice_eo_21092606.wav
# wavs/common_voice_eo_19688743.wav
# wavs/common_voice_eo_18709886.wav
# wavs/common_voice_eo_20742687.wav
# wavs/common_voice_eo_18850505.wav
# wavs/common_voice_eo_19331277.wav
# wavs/common_voice_eo_19542957.wav
# wavs/common_voice_eo_20501303.wav
# wavs/common_voice_eo_18092953.wav
# wavs/common_voice_eo_20973184.wav
# wavs/common_voice_eo_20462322.wav
# wavs/common_voice_eo_20091731.wav
# wavs/common_voice_eo_21189485.wav
# wavs/common_voice_eo_20432834.wav
# wavs/common_voice_eo_19414768.wav
# wavs/common_voice_eo_18336508.wav
# wavs/common_voice_eo_20956097.wav
# wavs/common_voice_eo_20852446.wav
# wavs/common_voice_eo_20197934.wav
# wavs/common_voice_eo_20210793.wav
# wavs/common_voice_eo_18593337.wav
# wavs/common_voice_eo_18709889.wav
# wavs/common_voice_eo_18677638.wav
# wavs/common_voice_eo_17945109.wav
# wavs/common_voice_eo_19795757.wav
# wavs/common_voice_eo_18146627.wav
# wavs/common_voice_eo_18545597.wav
# wavs/common_voice_eo_20373133.wav
# wavs/common_voice_eo_20454128.wav
# wavs/common_voice_eo_19247169.wav
# wavs/common_voice_eo_17907127.wav
# wavs/common_voice_eo_18591750.wav
# wavs/common_voice_eo_18976319.wav
# wavs/common_voice_eo_19750685.wav
# wavs/common_voice_eo_20495586.wav
# wavs/common_voice_eo_18488828.wav
# wavs/common_voice_eo_17916721.wav
# wavs/common_voice_eo_18607424.wav
# wavs/common_voice_eo_20091885.wav
# wavs/common_voice_eo_19841202.wav
# wavs/common_voice_eo_20504825.wav
# wavs/common_voice_eo_20861553.wav
# wavs/common_voice_eo_18422687.wav
# wavs/common_voice_eo_18597857.wav
# wavs/common_voice_eo_19343794.wav
# wavs/common_voice_eo_20873993.wav
# wavs/common_voice_eo_20719717.wav
# wavs/common_voice_eo_21337743.wav
# wavs/common_voice_eo_18127715.wav
# wavs/common_voice_eo_20370533.wav
# wavs/common_voice_eo_18052282.wav
# wavs/common_voice_eo_20637378.wav
# wavs/common_voice_eo_20450159.wav
# wavs/common_voice_eo_21355400.wav
# wavs/common_voice_eo_21261775.wav
# wavs/common_voice_eo_19474689.wav
# wavs/common_voice_eo_19247593.wav
# wavs/common_voice_eo_20637389.wav
# wavs/common_voice_eo_20527492.wav
# wavs/common_voice_eo_19863313.wav
# wavs/common_voice_eo_20424179.wav
# wavs/common_voice_eo_19422441.wav
# wavs/common_voice_eo_18826856.wav
# wavs/common_voice_eo_20454129.wav
# wavs/common_voice_eo_20446352.wav
# wavs/common_voice_eo_18563319.wav
# wavs/common_voice_eo_19855807.wav
# wavs/common_voice_eo_21348970.wav
# wavs/common_voice_eo_19788487.wav
# wavs/common_voice_eo_20519322.wav
# wavs/common_voice_eo_19854445.wav
# wavs/common_voice_eo_18611169.wav
# wavs/common_voice_eo_19787389.wav
# wavs/common_voice_eo_17994005.wav
# wavs/common_voice_eo_17912141.wav
# wavs/common_voice_eo_18997746.wav
# wavs/common_voice_eo_19543584.wav
# wavs/common_voice_eo_20486585.wav
# wavs/common_voice_eo_19543383.wav
# wavs/common_voice_eo_17906589.wav
# wavs/common_voice_eo_17961461.wav
# wavs/common_voice_eo_19422443.wav
# wavs/common_voice_eo_17961008.wav
# wavs/common_voice_eo_20816796.wav
# wavs/common_voice_eo_18420115.wav
# wavs/common_voice_eo_21487284.wav
# wavs/common_voice_eo_19773007.wav
# wavs/common_voice_eo_18591910.wav
# wavs/common_voice_eo_18297823.wav
# wavs/common_voice_eo_18420095.wav
# wavs/common_voice_eo_19773155.wav
# wavs/common_voice_eo_19419275.wav
# wavs/common_voice_eo_19818912.wav
# wavs/common_voice_eo_20779346.wav
# wavs/common_voice_eo_20423225.wav
# wavs/common_voice_eo_19957235.wav
# wavs/common_voice_eo_19297638.wav
# wavs/common_voice_eo_19855770.wav
# wavs/common_voice_eo_21487216.wav
# wavs/common_voice_eo_20753859.wav
# wavs/common_voice_eo_21240452.wav
# wavs/common_voice_eo_20453903.wav
# wavs/common_voice_eo_19543734.wav
# wavs/common_voice_eo_18871378.wav
# wavs/common_voice_eo_18871225.wav
# wavs/common_voice_eo_20446461.wav
# wavs/common_voice_eo_19412666.wav
# wavs/common_voice_eo_17937191.wav
# wavs/common_voice_eo_21011926.wav
# wavs/common_voice_eo_19786523.wav
# wavs/common_voice_eo_18398018.wav
# wavs/common_voice_eo_17900370.wav
# wavs/common_voice_eo_19817697.wav
# wavs/common_voice_eo_19336973.wav
# wavs/common_voice_eo_19855826.wav
# wavs/common_voice_eo_18871300.wav
# wavs/common_voice_eo_19863319.wav
# wavs/common_voice_eo_20734049.wav
# wavs/common_voice_eo_21365078.wav
# wavs/common_voice_eo_21304069.wav
# wavs/common_voice_eo_20216386.wav
# wavs/common_voice_eo_20464666.wav
# wavs/common_voice_eo_20216462.wav
# wavs/common_voice_eo_20527517.wav
# wavs/common_voice_eo_18048678.wav
# wavs/common_voice_eo_20504801.wav
# wavs/common_voice_eo_20472032.wav
# wavs/common_voice_eo_18597853.wav
# wavs/common_voice_eo_19844116.wav
# wavs/common_voice_eo_19870188.wav
# wavs/common_voice_eo_19859184.wav
# wavs/common_voice_eo_19854440.wav
# wavs/common_voice_eo_17916508.wav
# wavs/common_voice_eo_20518833.wav
# wavs/common_voice_eo_19368107.wav
# wavs/common_voice_eo_20301182.wav
# wavs/common_voice_eo_21515569.wav
# wavs/common_voice_eo_20717738.wav
# wavs/common_voice_eo_20308259.wav
# wavs/common_voice_eo_21245206.wav
# wavs/common_voice_eo_19870064.wav
# wavs/common_voice_eo_19414686.wav
# wavs/common_voice_eo_20856433.wav
# wavs/common_voice_eo_20878566.wav
# wavs/common_voice_eo_20717376.wav
# wavs/common_voice_eo_18866067.wav
# wavs/common_voice_eo_21180822.wav
# wavs/common_voice_eo_20694546.wav
# wavs/common_voice_eo_21236068.wav
# wavs/common_voice_eo_19819305.wav
# wavs/common_voice_eo_20425541.wav
# wavs/common_voice_eo_21184707.wav
# wavs/common_voice_eo_19870255.wav
# wavs/common_voice_eo_19782167.wav
# wavs/common_voice_eo_20497655.wav
# wavs/common_voice_eo_17908633.wav
# wavs/common_voice_eo_17937112.wav
# wavs/common_voice_eo_18545495.wav
# wavs/common_voice_eo_19005040.wav
# wavs/common_voice_eo_20346006.wav
# wavs/common_voice_eo_19543405.wav
# wavs/common_voice_eo_20254959.wav
# wavs/common_voice_eo_19526657.wav
# wavs/common_voice_eo_19820057.wav
# wavs/common_voice_eo_20486477.wav
# wavs/common_voice_eo_20962424.wav
# wavs/common_voice_eo_17933092.wav
# wavs/common_voice_eo_20725830.wav
# wavs/common_voice_eo_20475600.wav
# wavs/common_voice_eo_19308612.wav
# wavs/common_voice_eo_20719808.wav
# wavs/common_voice_eo_20791737.wav
# wavs/common_voice_eo_19774491.wav
# wavs/common_voice_eo_20504894.wav
# wavs/common_voice_eo_20227313.wav
# wavs/common_voice_eo_20987118.wav
# wavs/common_voice_eo_19802632.wav
# wavs/common_voice_eo_17961128.wav
# wavs/common_voice_eo_19545719.wav
# wavs/common_voice_eo_20921220.wav
# wavs/common_voice_eo_18336698.wav
# wavs/common_voice_eo_17900229.wav
# wavs/common_voice_eo_17957309.wav
# wavs/common_voice_eo_19844081.wav
# wavs/common_voice_eo_18639542.wav
# wavs/common_voice_eo_18492336.wav
# wavs/common_voice_eo_19347144.wav
# wavs/common_voice_eo_20677483.wav
# wavs/common_voice_eo_20466249.wav
# wavs/common_voice_eo_20591613.wav
# wavs/common_voice_eo_20502556.wav
# wavs/common_voice_eo_17898780.wav
# wavs/common_voice_eo_18591570.wav
# wavs/common_voice_eo_19087938.wav
# wavs/common_voice_eo_18015310.wav
# wavs/common_voice_eo_21334513.wav
# wavs/common_voice_eo_17912150.wav
# wavs/common_voice_eo_21085254.wav
# wavs/common_voice_eo_19860738.wav
# wavs/common_voice_eo_20861629.wav
# wavs/common_voice_eo_20905008.wav
# wavs/common_voice_eo_20482841.wav
# wavs/common_voice_eo_20981193.wav
# wavs/common_voice_eo_20490722.wav
# wavs/common_voice_eo_20229004.wav
# wavs/common_voice_eo_20877764.wav
# wavs/common_voice_eo_19039480.wav
# wavs/common_voice_eo_20461444.wav
# wavs/common_voice_eo_19868701.wav
# wavs/common_voice_eo_18439324.wav
# wavs/common_voice_eo_19859942.wav
# wavs/common_voice_eo_20884576.wav
# wavs/common_voice_eo_18488264.wav
# wavs/common_voice_eo_18072717.wav
# wavs/common_voice_eo_20489927.wav
# wavs/common_voice_eo_19870652.wav
# wavs/common_voice_eo_19848245.wav
# wavs/common_voice_eo_20487897.wav
# wavs/common_voice_eo_19658257.wav
# wavs/common_voice_eo_19036321.wav
# wavs/common_voice_eo_20908253.wav
# wavs/common_voice_eo_20434360.wav
# wavs/common_voice_eo_19860868.wav
# wavs/common_voice_eo_21136561.wav
# wavs/common_voice_eo_19776594.wav
# wavs/common_voice_eo_18790044.wav
# wavs/common_voice_eo_20596187.wav
# wavs/common_voice_eo_20501231.wav
# wavs/common_voice_eo_18790330.wav
# wavs/common_voice_eo_20557933.wav
# wavs/common_voice_eo_20307124.wav
# wavs/common_voice_eo_21314980.wav
# wavs/common_voice_eo_18585478.wav
# wavs/common_voice_eo_18730802.wav
# wavs/common_voice_eo_20688358.wav
# wavs/common_voice_eo_20103087.wav
# wavs/common_voice_eo_19287758.wav
# wavs/common_voice_eo_20944899.wav
# wavs/common_voice_eo_19321804.wav
# wavs/common_voice_eo_20427783.wav
# wavs/common_voice_eo_19419119.wav
# wavs/common_voice_eo_20846519.wav
# wavs/common_voice_eo_20330577.wav
# wavs/common_voice_eo_17907822.wav
# wavs/common_voice_eo_18012444.wav
# wavs/common_voice_eo_21485660.wav
# wavs/common_voice_eo_20816823.wav
# wavs/common_voice_eo_20664867.wav
# wavs/common_voice_eo_20307036.wav
# wavs/common_voice_eo_17926428.wav
# wavs/common_voice_eo_20425105.wav
# wavs/common_voice_eo_18355728.wav
# wavs/common_voice_eo_21267515.wav
# wavs/common_voice_eo_19871662.wav
# wavs/common_voice_eo_18871277.wav
# wavs/common_voice_eo_20222637.wav
# wavs/common_voice_eo_20778544.wav
# wavs/common_voice_eo_19496433.wav
# wavs/common_voice_eo_21226150.wav
# wavs/common_voice_eo_19414821.wav
# wavs/common_voice_eo_20576713.wav
# wavs/common_voice_eo_19860148.wav
# wavs/common_voice_eo_21335198.wav
# wavs/common_voice_eo_18591809.wav
# wavs/common_voice_eo_19788402.wav
# wavs/common_voice_eo_19039430.wav
# wavs/common_voice_eo_19800750.wav
# wavs/common_voice_eo_20796534.wav
# wavs/common_voice_eo_20439398.wav
# wavs/common_voice_eo_19776256.wav
# wavs/common_voice_eo_19114116.wav
# wavs/common_voice_eo_19860029.wav
# wavs/common_voice_eo_18483468.wav
# wavs/common_voice_eo_18437385.wav
# wavs/common_voice_eo_21394885.wav
# wavs/common_voice_eo_17999387.wav
# wavs/common_voice_eo_20673267.wav
# wavs/common_voice_eo_20640558.wav
# wavs/common_voice_eo_20270394.wav
# wavs/common_voice_eo_19827187.wav
# wavs/common_voice_eo_18668203.wav
# wavs/common_voice_eo_19555148.wav
# wavs/common_voice_eo_19827568.wav
# wavs/common_voice_eo_20958107.wav
# wavs/common_voice_eo_20015886.wav
# wavs/common_voice_eo_17919819.wav
# wavs/common_voice_eo_20677498.wav
# wavs/common_voice_eo_20664026.wav
# wavs/common_voice_eo_21515599.wav
# wavs/common_voice_eo_21487200.wav
# wavs/common_voice_eo_20189293.wav
# wavs/common_voice_eo_19737929.wav
# wavs/common_voice_eo_20602834.wav
# wavs/common_voice_eo_18591710.wav
# wavs/common_voice_eo_20474552.wav
# wavs/common_voice_eo_20734803.wav
# wavs/common_voice_eo_19498902.wav
# wavs/common_voice_eo_19400965.wav
# wavs/common_voice_eo_19887320.wav
# wavs/common_voice_eo_19823203.wav
# wavs/common_voice_eo_20501982.wav
# wavs/common_voice_eo_19431438.wav
# wavs/common_voice_eo_17937026.wav
# wavs/common_voice_eo_18862945.wav
# wavs/common_voice_eo_17899580.wav
# wavs/common_voice_eo_20489674.wav
# wavs/common_voice_eo_20850258.wav
# wavs/common_voice_eo_19860088.wav
# wavs/common_voice_eo_20427630.wav
# wavs/common_voice_eo_17919730.wav
# wavs/common_voice_eo_17975246.wav
# wavs/common_voice_eo_17913554.wav
# wavs/common_voice_eo_20372912.wav
# wavs/common_voice_eo_20842644.wav
# wavs/common_voice_eo_18460607.wav
# wavs/common_voice_eo_21059955.wav
# wavs/common_voice_eo_21051221.wav
# wavs/common_voice_eo_21077841.wav
# wavs/common_voice_eo_20964615.wav
# wavs/common_voice_eo_19327630.wav
# wavs/common_voice_eo_19337153.wav
# wavs/common_voice_eo_20735953.wav
# wavs/common_voice_eo_21358274.wav
# wavs/common_voice_eo_18600452.wav
# wavs/common_voice_eo_20506979.wav
# wavs/common_voice_eo_19543294.wav
# wavs/common_voice_eo_19343549.wav
# wavs/common_voice_eo_18488805.wav
# wavs/common_voice_eo_20694511.wav
# wavs/common_voice_eo_19127654.wav
# wavs/common_voice_eo_17961036.wav
# wavs/common_voice_eo_18052307.wav
# wavs/common_voice_eo_20202526.wav
# wavs/common_voice_eo_20466915.wav
# wavs/common_voice_eo_19252896.wav
# wavs/common_voice_eo_17911772.wav
# wavs/common_voice_eo_20732802.wav
# wavs/common_voice_eo_18433886.wav
# wavs/common_voice_eo_19235484.wav
# wavs/common_voice_eo_20432416.wav
# wavs/common_voice_eo_20957004.wav
# wavs/common_voice_eo_19336822.wav
# wavs/common_voice_eo_19427573.wav
# wavs/common_voice_eo_21486348.wav
# wavs/common_voice_eo_18585104.wav
# wavs/common_voice_eo_18871189.wav
# wavs/common_voice_eo_21158053.wav
# wavs/common_voice_eo_19821016.wav
# wavs/common_voice_eo_19893298.wav
# wavs/common_voice_eo_19827098.wav
# wavs/common_voice_eo_18495673.wav
# wavs/common_voice_eo_20791739.wav
# wavs/common_voice_eo_17970700.wav
# wavs/common_voice_eo_19114091.wav
# wavs/common_voice_eo_19555050.wav
# wavs/common_voice_eo_18507035.wav
# wavs/common_voice_eo_20496695.wav
# wavs/common_voice_eo_21368725.wav
# wavs/common_voice_eo_20423520.wav
# wavs/common_voice_eo_18563288.wav
# wavs/common_voice_eo_20735927.wav
# wavs/common_voice_eo_18488797.wav
# wavs/common_voice_eo_20501230.wav
# wavs/common_voice_eo_17907235.wav
# wavs/common_voice_eo_18668311.wav
# wavs/common_voice_eo_20427654.wav
# wavs/common_voice_eo_20779439.wav
# wavs/common_voice_eo_20485921.wav
# wavs/common_voice_eo_20709114.wav
# wavs/common_voice_eo_19870202.wav
# wavs/common_voice_eo_21273297.wav
# wavs/common_voice_eo_20203256.wav
# wavs/common_voice_eo_21300744.wav
# wavs/common_voice_eo_19543699.wav
# wavs/common_voice_eo_20640445.wav
# wavs/common_voice_eo_19419945.wav
# wavs/common_voice_eo_19427601.wav
# wavs/common_voice_eo_18492366.wav
# wavs/common_voice_eo_18298859.wav
# wavs/common_voice_eo_19837004.wav
# wavs/common_voice_eo_19822497.wav
# wavs/common_voice_eo_20479084.wav
# wavs/common_voice_eo_19555376.wav
# wavs/common_voice_eo_20462155.wav
# wavs/common_voice_eo_17956476.wav
# wavs/common_voice_eo_18109300.wav
# wavs/common_voice_eo_18563352.wav
# wavs/common_voice_eo_20680224.wav
# wavs/common_voice_eo_18563475.wav
# wavs/common_voice_eo_18727817.wav
# wavs/common_voice_eo_19714706.wav
# wavs/common_voice_eo_19820673.wav
# wavs/common_voice_eo_20669630.wav
# wavs/common_voice_eo_17898367.wav
# wavs/common_voice_eo_20482872.wav
# wavs/common_voice_eo_20873957.wav
# wavs/common_voice_eo_20483476.wav
# wavs/common_voice_eo_21253634.wav
# wavs/common_voice_eo_20962419.wav
# wavs/common_voice_eo_20879765.wav
# wavs/common_voice_eo_18592238.wav
# wavs/common_voice_eo_18668301.wav
# wavs/common_voice_eo_18983205.wav
# wavs/common_voice_eo_19820008.wav
# wavs/common_voice_eo_18590677.wav
# wavs/common_voice_eo_19738174.wav
# wavs/common_voice_eo_20779186.wav
# wavs/common_voice_eo_19277750.wav
# wavs/common_voice_eo_20425112.wav
# wavs/common_voice_eo_20868817.wav
# wavs/common_voice_eo_18336616.wav
# wavs/common_voice_eo_21089415.wav
# wavs/common_voice_eo_19355586.wav
# wavs/common_voice_eo_19474718.wav
# wavs/common_voice_eo_18460598.wav
# wavs/common_voice_eo_20908218.wav
# wavs/common_voice_eo_19316915.wav
# wavs/common_voice_eo_18460591.wav
# wavs/common_voice_eo_18545485.wav
# wavs/common_voice_eo_20779441.wav
# wavs/common_voice_eo_19247776.wav
# wavs/common_voice_eo_20956062.wav
# wavs/common_voice_eo_19381924.wav
# wavs/common_voice_eo_20841090.wav
# wavs/common_voice_eo_20561326.wav
# wavs/common_voice_eo_20527510.wav
# wavs/common_voice_eo_19827535.wav
# wavs/common_voice_eo_20214721.wav
# wavs/common_voice_eo_17907783.wav
# wavs/common_voice_eo_19368087.wav
# wavs/common_voice_eo_21502420.wav
# wavs/common_voice_eo_19129219.wav
# wavs/common_voice_eo_21312293.wav
# wavs/common_voice_eo_20483525.wav
# wavs/common_voice_eo_19808254.wav
# wavs/common_voice_eo_19127834.wav
# wavs/common_voice_eo_20182195.wav
# wavs/common_voice_eo_17898786.wav
# wavs/common_voice_eo_20430852.wav
# wavs/common_voice_eo_18835633.wav
# wavs/common_voice_eo_17922760.wav
# wavs/common_voice_eo_20501973.wav
# wavs/common_voice_eo_19387653.wav
# wavs/common_voice_eo_21448563.wav
# wavs/common_voice_eo_19335810.wav
# wavs/common_voice_eo_19788113.wav
# wavs/common_voice_eo_19732530.wav
# wavs/common_voice_eo_20520294.wav
# wavs/common_voice_eo_21235316.wav
# wavs/common_voice_eo_18033578.wav
# wavs/common_voice_eo_18992470.wav
# wavs/common_voice_eo_21015265.wav
# wavs/common_voice_eo_19308737.wav
# wavs/common_voice_eo_21235252.wav
# wavs/common_voice_eo_18049202.wav
# wavs/common_voice_eo_19343738.wav
# wavs/common_voice_eo_19449008.wav
# wavs/common_voice_eo_18471124.wav
# wavs/common_voice_eo_19543594.wav
# wavs/common_voice_eo_19631014.wav
# wavs/common_voice_eo_20670011.wav
# wavs/common_voice_eo_20842639.wav
# wavs/common_voice_eo_20424250.wav
# wavs/common_voice_eo_20406852.wav
# wavs/common_voice_eo_18728060.wav
# wavs/common_voice_eo_19820650.wav
# wavs/common_voice_eo_21217182.wav
# wavs/common_voice_eo_19543662.wav
# wavs/common_voice_eo_19368069.wav
# wavs/common_voice_eo_21349313.wav
# wavs/common_voice_eo_18075619.wav
# wavs/common_voice_eo_21358325.wav
# wavs/common_voice_eo_19757076.wav
# wavs/common_voice_eo_18674446.wav
# wavs/common_voice_eo_20905005.wav
# wavs/common_voice_eo_21437934.wav
# wavs/common_voice_eo_19265923.wav
# wavs/common_voice_eo_17900203.wav
# wavs/common_voice_eo_21059958.wav
# wavs/common_voice_eo_21304049.wav
# wavs/common_voice_eo_19786685.wav
# wavs/common_voice_eo_20809584.wav
# wavs/common_voice_eo_20856394.wav
# wavs/common_voice_eo_19845115.wav
# wavs/common_voice_eo_19729871.wav
# wavs/common_voice_eo_19870799.wav
# wavs/common_voice_eo_18591953.wav
# wavs/common_voice_eo_18871404.wav
# wavs/common_voice_eo_20846708.wav
# wavs/common_voice_eo_18575461.wav
# wavs/common_voice_eo_18639532.wav
# wavs/common_voice_eo_19449047.wav
# wavs/common_voice_eo_21180729.wav
# wavs/common_voice_eo_18567079.wav
# wavs/common_voice_eo_20015512.wav
# wavs/common_voice_eo_20884527.wav
# wavs/common_voice_eo_18866037.wav
# wavs/common_voice_eo_19358749.wav
# wavs/common_voice_eo_19326520.wav
# wavs/common_voice_eo_21519044.wav
# wavs/common_voice_eo_20816641.wav
# wavs/common_voice_eo_20474544.wav
# wavs/common_voice_eo_19419330.wav
# wavs/common_voice_eo_21330112.wav
# wavs/common_voice_eo_21326252.wav
# wavs/common_voice_eo_19337398.wav
# wavs/common_voice_eo_20856393.wav
# wavs/common_voice_eo_19127840.wav
# wavs/common_voice_eo_21512649.wav
# wavs/common_voice_eo_20782884.wav
# wavs/common_voice_eo_17908524.wav
# wavs/common_voice_eo_18846978.wav
# wavs/common_voice_eo_20691743.wav
# wavs/common_voice_eo_19856357.wav
# wavs/common_voice_eo_19265910.wav
# wavs/common_voice_eo_20873127.wav
# wavs/common_voice_eo_19252239.wav
# wavs/common_voice_eo_17961083.wav
# wavs/common_voice_eo_19355559.wav
# wavs/common_voice_eo_19876721.wav
# wavs/common_voice_eo_21293309.wav
# wavs/common_voice_eo_18592248.wav
# wavs/common_voice_eo_20577147.wav
# wavs/common_voice_eo_20886510.wav
# wavs/common_voice_eo_20381132.wav
# wavs/common_voice_eo_19788015.wav
# wavs/common_voice_eo_20809434.wav
# wavs/common_voice_eo_18874840.wav
# wavs/common_voice_eo_19714748.wav
# wavs/common_voice_eo_19427431.wav
# wavs/common_voice_eo_20182194.wav
# wavs/common_voice_eo_21386438.wav
# wavs/common_voice_eo_19098600.wav
# wavs/common_voice_eo_17907269.wav
# wavs/common_voice_eo_19780474.wav
# wavs/common_voice_eo_19819964.wav
# wavs/common_voice_eo_20820887.wav
# wavs/common_voice_eo_19864773.wav
# wavs/common_voice_eo_21445411.wav
# wavs/common_voice_eo_18835772.wav
# wavs/common_voice_eo_21051141.wav
# wavs/common_voice_eo_18503550.wav
# wavs/common_voice_eo_19755561.wav
# wavs/common_voice_eo_17898959.wav
# wavs/common_voice_eo_17899015.wav
# wavs/common_voice_eo_20960319.wav
# wavs/common_voice_eo_21502527.wav
# wavs/common_voice_eo_19284567.wav
# wavs/common_voice_eo_19346467.wav
# wavs/common_voice_eo_20425654.wav
# wavs/common_voice_eo_19750451.wav
# wavs/common_voice_eo_17912159.wav
# wavs/common_voice_eo_19870061.wav
# wavs/common_voice_eo_20558784.wav
# wavs/common_voice_eo_18545423.wav
# wavs/common_voice_eo_19781585.wav
# wavs/common_voice_eo_20468258.wav
# wavs/common_voice_eo_18460605.wav
# wavs/common_voice_eo_21377077.wav
# wavs/common_voice_eo_20882062.wav
# wavs/common_voice_eo_19827173.wav
# wavs/common_voice_eo_18492374.wav
# wavs/common_voice_eo_20475996.wav
# wavs/common_voice_eo_18807156.wav
# wavs/common_voice_eo_18677624.wav
# wavs/common_voice_eo_20657713.wav
# wavs/common_voice_eo_19317193.wav
# wavs/common_voice_eo_20644146.wav
# wavs/common_voice_eo_20655139.wav
# wavs/common_voice_eo_20223880.wav
# wavs/common_voice_eo_20424116.wav
# wavs/common_voice_eo_19554979.wav
# wavs/common_voice_eo_20981012.wav
# wavs/common_voice_eo_20372949.wav
# wavs/common_voice_eo_19818882.wav
# wavs/common_voice_eo_18176564.wav
# wavs/common_voice_eo_19257718.wav
# wavs/common_voice_eo_19868708.wav
# wavs/common_voice_eo_18018755.wav
# wavs/common_voice_eo_20506944.wav
# wavs/common_voice_eo_20372972.wav
# wavs/common_voice_eo_20908251.wav
# wavs/common_voice_eo_19658137.wav
# wavs/common_voice_eo_19584082.wav
# wavs/common_voice_eo_20427049.wav
# wavs/common_voice_eo_20373149.wav
# wavs/common_voice_eo_17899644.wav
# wavs/common_voice_eo_18498360.wav
# wavs/common_voice_eo_21077839.wav
# wavs/common_voice_eo_19863321.wav
# wavs/common_voice_eo_17908043.wav
# wavs/common_voice_eo_18078719.wav
# wavs/common_voice_eo_19247129.wav
# wavs/common_voice_eo_20617728.wav
# wavs/common_voice_eo_17945225.wav
# wavs/common_voice_eo_20466886.wav
# wavs/common_voice_eo_17899586.wav
# wavs/common_voice_eo_19504481.wav
# wavs/common_voice_eo_19027784.wav
# wavs/common_voice_eo_18153933.wav
# wavs/common_voice_eo_20791724.wav
# wavs/common_voice_eo_21128083.wav
# wavs/common_voice_eo_21236312.wav
# wavs/common_voice_eo_20881383.wav
# wavs/common_voice_eo_20981111.wav
# wavs/common_voice_eo_18591366.wav
# wavs/common_voice_eo_20816990.wav
# wavs/common_voice_eo_18063280.wav
# wavs/common_voice_eo_21485425.wav
# wavs/common_voice_eo_19253260.wav
# wavs/common_voice_eo_21262056.wav
# wavs/common_voice_eo_18728045.wav
# wavs/common_voice_eo_19853650.wav
# wavs/common_voice_eo_20960347.wav
# wavs/common_voice_eo_18746575.wav
# wavs/common_voice_eo_20432591.wav
# wavs/common_voice_eo_21419118.wav
# wavs/common_voice_eo_19419885.wav
# wavs/common_voice_eo_18584235.wav
# wavs/common_voice_eo_19854879.wav
# wavs/common_voice_eo_18674436.wav
# wavs/common_voice_eo_17898934.wav
# wavs/common_voice_eo_18724895.wav
# wavs/common_voice_eo_20501989.wav
# wavs/common_voice_eo_20688334.wav
# wavs/common_voice_eo_19422471.wav
# wavs/common_voice_eo_17903434.wav
# wavs/common_voice_eo_21261956.wav
# wavs/common_voice_eo_21189551.wav
# wavs/common_voice_eo_19758993.wav
# wavs/common_voice_eo_20568278.wav
# wavs/common_voice_eo_20373139.wav
# wavs/common_voice_eo_17957231.wav
# wavs/common_voice_eo_18631313.wav
# wavs/common_voice_eo_20600683.wav
# wavs/common_voice_eo_20973382.wav
# wavs/common_voice_eo_18611166.wav
# wavs/common_voice_eo_19757086.wav
# wavs/common_voice_eo_19788209.wav
# wavs/common_voice_eo_20434419.wav
# wavs/common_voice_eo_18563269.wav
# wavs/common_voice_eo_19308753.wav
# wavs/common_voice_eo_17899013.wav
# wavs/common_voice_eo_20439388.wav
# wavs/common_voice_eo_19381931.wav
# wavs/common_voice_eo_17922795.wav
# wavs/common_voice_eo_19127981.wav
# wavs/common_voice_eo_19317330.wav
# wavs/common_voice_eo_21330170.wav
# wavs/common_voice_eo_20905036.wav
# wavs/common_voice_eo_18584307.wav
# wavs/common_voice_eo_20511797.wav
# wavs/common_voice_eo_18850507.wav
# wavs/common_voice_eo_18005639.wav
# wavs/common_voice_eo_20527501.wav
# wavs/common_voice_eo_19137032.wav
# wavs/common_voice_eo_21178887.wav
# wavs/common_voice_eo_20816645.wav
# wavs/common_voice_eo_20796451.wav
# wavs/common_voice_eo_20812515.wav
# wavs/common_voice_eo_20425118.wav
# wavs/common_voice_eo_18545101.wav
# wavs/common_voice_eo_20461493.wav
# wavs/common_voice_eo_20821346.wav
# wavs/common_voice_eo_18590647.wav
# wavs/common_voice_eo_20342231.wav
# wavs/common_voice_eo_20188937.wav
# wavs/common_voice_eo_18591545.wav
# wavs/common_voice_eo_21419239.wav
# wavs/common_voice_eo_20501985.wav
# wavs/common_voice_eo_19116227.wav
# wavs/common_voice_eo_17935809.wav
# wavs/common_voice_eo_20782850.wav
# wavs/common_voice_eo_20237403.wav
# wavs/common_voice_eo_20968115.wav
# wavs/common_voice_eo_19793268.wav
# wavs/common_voice_eo_19871810.wav
# wavs/common_voice_eo_19842433.wav
# wavs/common_voice_eo_21365090.wav
# wavs/common_voice_eo_20467224.wav
# wavs/common_voice_eo_17912053.wav
# wavs/common_voice_eo_20575866.wav
# wavs/common_voice_eo_20201787.wav
# wavs/common_voice_eo_19819302.wav
# wavs/common_voice_eo_20801386.wav
# wavs/common_voice_eo_18584289.wav
# wavs/common_voice_eo_21076440.wav
# wavs/common_voice_eo_17908624.wav
# wavs/common_voice_eo_20771090.wav
# wavs/common_voice_eo_19788481.wav
# wavs/common_voice_eo_17910143.wav
# wavs/common_voice_eo_20212146.wav
# wavs/common_voice_eo_21099172.wav
# wavs/common_voice_eo_19820753.wav
# wavs/common_voice_eo_21235652.wav
# wavs/common_voice_eo_17934621.wav
# wavs/common_voice_eo_20460967.wav
# wavs/common_voice_eo_21299296.wav
# wavs/common_voice_eo_18591792.wav
# wavs/common_voice_eo_18587428.wav
# wavs/common_voice_eo_19458007.wav
# wavs/common_voice_eo_20948555.wav
# wavs/common_voice_eo_20870843.wav
# wavs/common_voice_eo_19887292.wav
# wavs/common_voice_eo_19870312.wav
# wavs/common_voice_eo_19337360.wav
# wavs/common_voice_eo_20461669.wav
# wavs/common_voice_eo_18483476.wav
# wavs/common_voice_eo_20644176.wav
# wavs/common_voice_eo_18640560.wav
# wavs/common_voice_eo_20882142.wav
# wavs/common_voice_eo_20464623.wav
# wavs/common_voice_eo_17989950.wav
# wavs/common_voice_eo_19129212.wav
# wavs/common_voice_eo_18075927.wav
# wavs/common_voice_eo_19343543.wav
# wavs/common_voice_eo_20428645.wav
# wavs/common_voice_eo_21486240.wav
# wavs/common_voice_eo_19845977.wav
# wavs/common_voice_eo_18547535.wav
# wavs/common_voice_eo_20527481.wav
# wavs/common_voice_eo_17912031.wav
# wavs/common_voice_eo_20649963.wav
# wavs/common_voice_eo_17898698.wav
# wavs/common_voice_eo_20962420.wav
# wavs/common_voice_eo_19129431.wav
# wavs/common_voice_eo_18790059.wav
# wavs/common_voice_eo_19845083.wav
# wavs/common_voice_eo_19774461.wav
# wavs/common_voice_eo_20782758.wav
# wavs/common_voice_eo_17916706.wav
# wavs/common_voice_eo_20424259.wav
# wavs/common_voice_eo_19855725.wav
# wavs/common_voice_eo_18674450.wav
# wavs/common_voice_eo_20520259.wav
# wavs/common_voice_eo_17892998.wav
# wavs/common_voice_eo_20477493.wav
# wavs/common_voice_eo_20886490.wav
# wavs/common_voice_eo_20425129.wav
# wavs/common_voice_eo_18593364.wav
# wavs/common_voice_eo_19819920.wav
# wavs/common_voice_eo_19343609.wav
# wavs/common_voice_eo_20962455.wav
# wavs/common_voice_eo_18127711.wav
# wavs/common_voice_eo_17899549.wav
# wavs/common_voice_eo_20427695.wav
# wavs/common_voice_eo_19069653.wav
# wavs/common_voice_eo_17956362.wav
# wavs/common_voice_eo_21337797.wav
# wavs/common_voice_eo_20677551.wav
# wavs/common_voice_eo_19891333.wav
# wavs/common_voice_eo_20779156.wav
# wavs/common_voice_eo_20734108.wav
# wavs/common_voice_eo_20341808.wav
# wavs/common_voice_eo_18056511.wav
# wavs/common_voice_eo_18607406.wav
# wavs/common_voice_eo_20640816.wav
# wavs/common_voice_eo_19039470.wav
# wavs/common_voice_eo_18607488.wav
# wavs/common_voice_eo_19427508.wav
# wavs/common_voice_eo_17957300.wav
# wavs/common_voice_eo_18439293.wav
# wavs/common_voice_eo_18336656.wav
# wavs/common_voice_eo_19714675.wav
# wavs/common_voice_eo_18044462.wav
# wavs/common_voice_eo_21052139.wav
# wavs/common_voice_eo_20961386.wav
# wavs/common_voice_eo_21419144.wav
# wavs/common_voice_eo_20742647.wav
# wavs/common_voice_eo_19543743.wav
# wavs/common_voice_eo_18592191.wav
# wavs/common_voice_eo_20427843.wav
# wavs/common_voice_eo_19755074.wav
# wavs/common_voice_eo_19715315.wav
# wavs/common_voice_eo_19504792.wav
# wavs/common_voice_eo_21486391.wav
# wavs/common_voice_eo_21138179.wav
# wavs/common_voice_eo_18592237.wav
# wavs/common_voice_eo_19250815.wav
# wavs/common_voice_eo_19355480.wav
# wavs/common_voice_eo_20241814.wav
# wavs/common_voice_eo_20475924.wav
# wavs/common_voice_eo_20004141.wav
# wavs/common_voice_eo_17909171.wav
# wavs/common_voice_eo_20816751.wav
# wavs/common_voice_eo_20776869.wav
# wavs/common_voice_eo_19460037.wav
# wavs/common_voice_eo_20232614.wav
# wavs/common_voice_eo_20433138.wav
# wavs/common_voice_eo_20970155.wav
# wavs/common_voice_eo_19842022.wav
# wavs/common_voice_eo_20925781.wav
# wavs/common_voice_eo_19414934.wav
# wavs/common_voice_eo_19396275.wav
# wavs/common_voice_eo_20488110.wav
# wavs/common_voice_eo_19867325.wav
# wavs/common_voice_eo_20846698.wav
# wavs/common_voice_eo_21262062.wav
# wavs/common_voice_eo_19668424.wav
# wavs/common_voice_eo_19827202.wav
# wavs/common_voice_eo_20424344.wav
# wavs/common_voice_eo_19358752.wav
# wavs/common_voice_eo_19847972.wav
# wavs/common_voice_eo_20949394.wav
# wavs/common_voice_eo_19336842.wav
# wavs/common_voice_eo_19802496.wav
# wavs/common_voice_eo_18607289.wav
# wavs/common_voice_eo_20433094.wav
# wavs/common_voice_eo_19820698.wav
# wavs/common_voice_eo_18945228.wav
# wavs/common_voice_eo_20489745.wav
# wavs/common_voice_eo_18868826.wav
# wavs/common_voice_eo_21077814.wav
# wavs/common_voice_eo_19543359.wav
# wavs/common_voice_eo_20590741.wav
# wavs/common_voice_eo_20496757.wav
# wavs/common_voice_eo_20016522.wav
# wavs/common_voice_eo_20719749.wav
# wavs/common_voice_eo_17957214.wav
# wavs/common_voice_eo_18433782.wav
# wavs/common_voice_eo_20425146.wav
# wavs/common_voice_eo_18135296.wav
# wavs/common_voice_eo_21512431.wav
# wavs/common_voice_eo_18707814.wav
# wavs/common_voice_eo_19478292.wav
# wavs/common_voice_eo_19481217.wav
# wavs/common_voice_eo_20091904.wav
# wavs/common_voice_eo_18668167.wav
# wavs/common_voice_eo_19543139.wav
# wavs/common_voice_eo_20212221.wav
# wavs/common_voice_eo_20410264.wav
# wavs/common_voice_eo_20425121.wav
# wavs/common_voice_eo_21089381.wav
# wavs/common_voice_eo_19526682.wav
# wavs/common_voice_eo_18728056.wav
# wavs/common_voice_eo_20782861.wav
# wavs/common_voice_eo_21012915.wav
# wavs/common_voice_eo_18569307.wav
# wavs/common_voice_eo_19957234.wav
# wavs/common_voice_eo_21094044.wav
# wavs/common_voice_eo_19431504.wav
# wavs/common_voice_eo_19504601.wav
# wavs/common_voice_eo_18358490.wav
# wavs/common_voice_eo_18563262.wav
# wavs/common_voice_eo_19422484.wav
# wavs/common_voice_eo_20426210.wav
# wavs/common_voice_eo_20973035.wav
# wavs/common_voice_eo_20489676.wav
# wavs/common_voice_eo_17966297.wav
# wavs/common_voice_eo_21014449.wav
# wavs/common_voice_eo_19837571.wav
# wavs/common_voice_eo_17916733.wav
# wavs/common_voice_eo_19867755.wav
# wavs/common_voice_eo_18607516.wav
# wavs/common_voice_eo_17916470.wav
# wavs/common_voice_eo_18591706.wav
# wavs/common_voice_eo_19329046.wav
# wavs/common_voice_eo_19506966.wav
# wavs/common_voice_eo_17926361.wav
# wavs/common_voice_eo_20212187.wav
# wavs/common_voice_eo_20561212.wav
# wavs/common_voice_eo_20846711.wav
# wavs/common_voice_eo_19668345.wav
# wavs/common_voice_eo_19820669.wav
# wavs/common_voice_eo_21335319.wav
# wavs/common_voice_eo_20465098.wav
# wavs/common_voice_eo_19841648.wav
# wavs/common_voice_eo_20270148.wav
# wavs/common_voice_eo_18896120.wav
# wavs/common_voice_eo_20561699.wav
# wavs/common_voice_eo_17937054.wav
# wavs/common_voice_eo_18584734.wav
# wavs/common_voice_eo_17960860.wav
# wavs/common_voice_eo_20326572.wav
# wavs/common_voice_eo_20410277.wav
# wavs/common_voice_eo_20970115.wav
# wavs/common_voice_eo_19504671.wav
# wavs/common_voice_eo_20617655.wav
# wavs/common_voice_eo_20821187.wav
# wavs/common_voice_eo_21374457.wav
# wavs/common_voice_eo_21304592.wav
# wavs/common_voice_eo_20544525.wav
# wavs/common_voice_eo_19875811.wav
# wavs/common_voice_eo_20455837.wav
# wavs/common_voice_eo_19514130.wav
# wavs/common_voice_eo_18046187.wav
# wavs/common_voice_eo_19750312.wav
# wavs/common_voice_eo_21223819.wav
# wavs/common_voice_eo_17906709.wav
# wavs/common_voice_eo_18547975.wav
# wavs/common_voice_eo_20673270.wav
# wavs/common_voice_eo_18879832.wav
# wavs/common_voice_eo_20861585.wav
# wavs/common_voice_eo_18575474.wav
# wavs/common_voice_eo_20453687.wav
# wavs/common_voice_eo_19788393.wav
# wavs/common_voice_eo_19543649.wav
# wavs/common_voice_eo_21515697.wav
# wavs/common_voice_eo_18966330.wav
# wavs/common_voice_eo_18714033.wav
# wavs/common_voice_eo_20592020.wav
# wavs/common_voice_eo_19887224.wav
# wavs/common_voice_eo_19730125.wav
# wavs/common_voice_eo_21099398.wav
# wavs/common_voice_eo_19870073.wav
# wavs/common_voice_eo_19765440.wav
# wavs/common_voice_eo_20209365.wav
# wavs/common_voice_eo_19266244.wav
# wavs/common_voice_eo_18000632.wav
# wavs/common_voice_eo_20427578.wav
# wavs/common_voice_eo_18415129.wav
# wavs/common_voice_eo_21399210.wav
# wavs/common_voice_eo_21349445.wav
# wavs/common_voice_eo_20451868.wav
# wavs/common_voice_eo_21089407.wav
# wavs/common_voice_eo_19116132.wav
# wavs/common_voice_eo_19688827.wav
# wavs/common_voice_eo_19316740.wav
# wavs/common_voice_eo_18972315.wav
# wavs/common_voice_eo_19788210.wav
# wavs/common_voice_eo_19103301.wav
# wavs/common_voice_eo_19317450.wav
# wavs/common_voice_eo_20466991.wav
# wavs/common_voice_eo_17997911.wav
# wavs/common_voice_eo_17923669.wav
# wavs/common_voice_eo_18841833.wav
# wavs/common_voice_eo_21445412.wav
# wavs/common_voice_eo_19355637.wav
# wavs/common_voice_eo_20474612.wav
# wavs/common_voice_eo_19317561.wav
# wavs/common_voice_eo_20617373.wav
# wavs/common_voice_eo_19337631.wav
# wavs/common_voice_eo_20664874.wav
# wavs/common_voice_eo_20465574.wav
# wavs/common_voice_eo_20829352.wav
# wavs/common_voice_eo_20688385.wav
# wavs/common_voice_eo_18175877.wav
# wavs/common_voice_eo_19827172.wav
# wavs/common_voice_eo_21050767.wav
# wavs/common_voice_eo_20465145.wav
# wavs/common_voice_eo_19782100.wav
# wavs/common_voice_eo_21319281.wav
# ...
# wavs/common_voice_eo_20719786.wav
# wavs/common_voice_eo_20442604.wav
# wavs/common_voice_eo_19844021.wav
# wavs/common_voice_eo_20561601.wav
# wavs/common_voice_eo_19012216.wav
# wavs/common_voice_eo_17908238.wav
# wavs/common_voice_eo_17934547.wav
# wavs/common_voice_eo_19458021.wav
# wavs/common_voice_eo_20432802.wav
# wavs/common_voice_eo_19284568.wav
# wavs/common_voice_eo_20908217.wav
# wavs/common_voice_eo_21072855.wav
# wavs/common_voice_eo_19504637.wav
# wavs/common_voice_eo_21200389.wav
# wavs/common_voice_eo_20868775.wav
# wavs/common_voice_eo_18506907.wav
# wavs/common_voice_eo_21485588.wav
# wavs/common_voice_eo_20662994.wav
# wavs/common_voice_eo_17906942.wav
# wavs/common_voice_eo_20425017.wav
# wavs/common_voice_eo_17945169.wav
# wavs/common_voice_eo_18005614.wav
# wavs/common_voice_eo_18889156.wav
# wavs/common_voice_eo_20486115.wav
# wavs/common_voice_eo_17898272.wav
# wavs/common_voice_eo_17935662.wav
# wavs/common_voice_eo_20459912.wav
# wavs/common_voice_eo_20920852.wav
# wavs/common_voice_eo_18511269.wav
# wavs/common_voice_eo_17993999.wav
# wavs/common_voice_eo_20925975.wav
# wavs/common_voice_eo_19452374.wav
# wavs/common_voice_eo_18863150.wav
# wavs/common_voice_eo_19855760.wav
# wavs/common_voice_eo_18941970.wav
# wavs/common_voice_eo_19478281.wav
# wavs/common_voice_eo_20960298.wav
# wavs/common_voice_eo_20341483.wav
# wavs/common_voice_eo_20461526.wav
# wavs/common_voice_eo_19422518.wav
# wavs/common_voice_eo_21364700.wav
# wavs/common_voice_eo_21128417.wav
# wavs/common_voice_eo_19355679.wav
# wavs/common_voice_eo_19848258.wav
# wavs/common_voice_eo_21299447.wav
# wavs/common_voice_eo_20973359.wav
# wavs/common_voice_eo_20119547.wav
# wavs/common_voice_eo_19129342.wav
# wavs/common_voice_eo_20811479.wav
# wavs/common_voice_eo_19543658.wav
# wavs/common_voice_eo_17908570.wav
# wavs/common_voice_eo_19229560.wav
# wavs/common_voice_eo_19844005.wav
# wavs/common_voice_eo_20688325.wav
# wavs/common_voice_eo_18433763.wav
# wavs/common_voice_eo_19808191.wav
# wavs/common_voice_eo_19062621.wav
# wavs/common_voice_eo_19815306.wav
# wavs/common_voice_eo_20758936.wav
# wavs/common_voice_eo_19326518.wav
# wavs/common_voice_eo_19461658.wav
# wavs/common_voice_eo_20719575.wav
# wavs/common_voice_eo_20527534.wav
# wavs/common_voice_eo_19521388.wav
# wavs/common_voice_eo_17902930.wav
# wavs/common_voice_eo_20664856.wav
# wavs/common_voice_eo_20227326.wav
# wavs/common_voice_eo_21078217.wav
# wavs/common_voice_eo_20794727.wav
# wavs/common_voice_eo_20319275.wav
# wavs/common_voice_eo_19111460.wav
# wavs/common_voice_eo_21092609.wav
# wavs/common_voice_eo_20754186.wav
# wavs/common_voice_eo_19870590.wav
# wavs/common_voice_eo_20496665.wav
# wavs/common_voice_eo_17911974.wav
# wavs/common_voice_eo_17907983.wav
# wavs/common_voice_eo_20956100.wav
# wavs/common_voice_eo_20504856.wav
# wavs/common_voice_eo_20378493.wav
# wavs/common_voice_eo_18257403.wav
# wavs/common_voice_eo_18668097.wav
# wavs/common_voice_eo_18591962.wav
# wavs/common_voice_eo_21201877.wav
# wavs/common_voice_eo_20882124.wav
# wavs/common_voice_eo_19886662.wav
# wavs/common_voice_eo_19750693.wav
# wavs/common_voice_eo_19415030.wav
# wavs/common_voice_eo_19788575.wav
# wavs/common_voice_eo_19853642.wav
# wavs/common_voice_eo_21368730.wav
# wavs/common_voice_eo_18244236.wav
# wavs/common_voice_eo_19802333.wav
# wavs/common_voice_eo_20891428.wav
# wavs/common_voice_eo_19381909.wav
# wavs/common_voice_eo_19486831.wav
# wavs/common_voice_eo_19870545.wav
# wavs/common_voice_eo_18727798.wav
# wavs/common_voice_eo_20423196.wav
# wavs/common_voice_eo_19836979.wav
# wavs/common_voice_eo_21304071.wav
# wavs/common_voice_eo_19474710.wav
# wavs/common_voice_eo_20701068.wav
# wavs/common_voice_eo_20450057.wav
# wavs/common_voice_eo_18238857.wav
# wavs/common_voice_eo_21502453.wav
# wavs/common_voice_eo_17898348.wav
# wavs/common_voice_eo_21328034.wav
# wavs/common_voice_eo_20463558.wav
# wavs/common_voice_eo_19496439.wav
# wavs/common_voice_eo_19427389.wav
# wavs/common_voice_eo_19871682.wav
# wavs/common_voice_eo_19823190.wav
# wavs/common_voice_eo_18446755.wav
# wavs/common_voice_eo_19316809.wav
# wavs/common_voice_eo_21110805.wav
# wavs/common_voice_eo_20829473.wav
# wavs/common_voice_eo_20427009.wav
# wavs/common_voice_eo_18556527.wav
# wavs/common_voice_eo_18257418.wav
# wavs/common_voice_eo_20732891.wav
# wavs/common_voice_eo_20575874.wav
# wavs/common_voice_eo_20521530.wav
# wavs/common_voice_eo_17923048.wav
# wavs/common_voice_eo_20468229.wav
# wavs/common_voice_eo_20820626.wav
# wavs/common_voice_eo_18545144.wav
# wavs/common_voice_eo_20725874.wav
# wavs/common_voice_eo_17933041.wav
# wavs/common_voice_eo_20432835.wav
# wavs/common_voice_eo_19090330.wav
# wavs/common_voice_eo_20511781.wav
# wavs/common_voice_eo_19580938.wav
# wavs/common_voice_eo_20742679.wav
# wavs/common_voice_eo_19458020.wav
# wavs/common_voice_eo_20427693.wav
# wavs/common_voice_eo_18608476.wav
# wavs/common_voice_eo_20994079.wav
# wavs/common_voice_eo_17903424.wav
# wavs/common_voice_eo_20856423.wav
# wavs/common_voice_eo_17961178.wav
# wavs/common_voice_eo_21315046.wav
# wavs/common_voice_eo_19467805.wav
# wavs/common_voice_eo_20731390.wav
# wavs/common_voice_eo_19859437.wav
# wavs/common_voice_eo_17908058.wav
# wavs/common_voice_eo_21067106.wav
# wavs/common_voice_eo_20497579.wav
# wavs/common_voice_eo_20486341.wav
# wavs/common_voice_eo_19860751.wav
# wavs/common_voice_eo_17957227.wav
# wavs/common_voice_eo_18876599.wav
# wavs/common_voice_eo_21184882.wav
# wavs/common_voice_eo_20669627.wav
# wavs/common_voice_eo_19321803.wav
# wavs/common_voice_eo_20493775.wav
# wavs/common_voice_eo_20558605.wav
# wavs/common_voice_eo_17909803.wav
# wavs/common_voice_eo_18724940.wav
# wavs/common_voice_eo_20598184.wav
# wavs/common_voice_eo_19711490.wav
# wavs/common_voice_eo_19854450.wav
# wavs/common_voice_eo_18816845.wav
# wavs/common_voice_eo_19868707.wav
# wavs/common_voice_eo_17937083.wav
# wavs/common_voice_eo_18873861.wav
# wavs/common_voice_eo_20743586.wav
# wavs/common_voice_eo_19329734.wav
# wavs/common_voice_eo_19250813.wav
# wavs/common_voice_eo_20520328.wav
# wavs/common_voice_eo_18336691.wav
# wavs/common_voice_eo_20850393.wav
# wavs/common_voice_eo_18546634.wav
# wavs/common_voice_eo_21351787.wav
# wavs/common_voice_eo_17985770.wav
# wavs/common_voice_eo_20452643.wav
# wavs/common_voice_eo_19658308.wav
# wavs/common_voice_eo_21137590.wav
# wavs/common_voice_eo_18588135.wav
# wavs/common_voice_eo_20357059.wav
# wavs/common_voice_eo_20644240.wav
# wavs/common_voice_eo_19400928.wav
# wavs/common_voice_eo_21319268.wav
# wavs/common_voice_eo_20617301.wav
# wavs/common_voice_eo_17985766.wav
# wavs/common_voice_eo_20439829.wav
# wavs/common_voice_eo_17898788.wav
# wavs/common_voice_eo_21085181.wav
# wavs/common_voice_eo_20820872.wav
# wavs/common_voice_eo_18838768.wav
# wavs/common_voice_eo_21004811.wav
# wavs/common_voice_eo_18023518.wav
# wavs/common_voice_eo_20958050.wav
# wavs/common_voice_eo_17908587.wav
# wavs/common_voice_eo_20688496.wav
# wavs/common_voice_eo_20779191.wav
# wavs/common_voice_eo_20577091.wav
# wavs/common_voice_eo_19275864.wav
# wavs/common_voice_eo_20372914.wav
# wavs/common_voice_eo_21164711.wav
# wavs/common_voice_eo_20207857.wav
# wavs/common_voice_eo_18563402.wav
# wavs/common_voice_eo_17902579.wav
# wavs/common_voice_eo_17916563.wav
# wavs/common_voice_eo_20561537.wav
# wavs/common_voice_eo_20946334.wav
# wavs/common_voice_eo_20224052.wav
# wavs/common_voice_eo_20908206.wav
# wavs/common_voice_eo_19788579.wav
# wavs/common_voice_eo_18075620.wav
# wavs/common_voice_eo_17908329.wav
# wavs/common_voice_eo_20891303.wav
# wavs/common_voice_eo_19128500.wav
# wavs/common_voice_eo_19355664.wav
# wavs/common_voice_eo_19776613.wav
# wavs/common_voice_eo_18556579.wav
# wavs/common_voice_eo_20560236.wav
# wavs/common_voice_eo_17907291.wav
# wavs/common_voice_eo_17908458.wav
# wavs/common_voice_eo_17926223.wav
# wavs/common_voice_eo_20502129.wav
# wavs/common_voice_eo_20856419.wav
# wavs/common_voice_eo_19317509.wav
# wavs/common_voice_eo_17922319.wav
# wavs/common_voice_eo_19859372.wav
# wavs/common_voice_eo_19815282.wav
# wavs/common_voice_eo_20502059.wav
# wavs/common_voice_eo_18048662.wav
# wavs/common_voice_eo_19253459.wav
# wavs/common_voice_eo_17911889.wav
# wavs/common_voice_eo_20345407.wav
# wavs/common_voice_eo_20696828.wav
# wavs/common_voice_eo_18607415.wav
# wavs/common_voice_eo_21061480.wav
# wavs/common_voice_eo_20679659.wav
# wavs/common_voice_eo_18863614.wav
# wavs/common_voice_eo_21304058.wav
# wavs/common_voice_eo_18336615.wav
# wavs/common_voice_eo_20434347.wav
# wavs/common_voice_eo_19776662.wav
# wavs/common_voice_eo_19128501.wav
# wavs/common_voice_eo_19272184.wav
# wavs/common_voice_eo_20427715.wav
# wavs/common_voice_eo_20424115.wav
# wavs/common_voice_eo_19355523.wav
# wavs/common_voice_eo_20868825.wav
# wavs/common_voice_eo_17919801.wav
# wavs/common_voice_eo_17934615.wav
# wavs/common_voice_eo_20207844.wav
# wavs/common_voice_eo_20093441.wav
# wavs/common_voice_eo_19826906.wav
# wavs/common_voice_eo_21138155.wav
# wavs/common_voice_eo_20424241.wav
# wavs/common_voice_eo_18828148.wav
# wavs/common_voice_eo_19257736.wav
# wavs/common_voice_eo_20519088.wav
# wavs/common_voice_eo_20835036.wav
# wavs/common_voice_eo_17911813.wav
# wavs/common_voice_eo_18997144.wav
# wavs/common_voice_eo_17918880.wav
# wavs/common_voice_eo_21181430.wav
# wavs/common_voice_eo_20563074.wav
# wavs/common_voice_eo_19551287.wav
# wavs/common_voice_eo_18611313.wav
# wavs/common_voice_eo_18488759.wav
# wavs/common_voice_eo_20816755.wav
# wavs/common_voice_eo_20817060.wav
# wavs/common_voice_eo_20905025.wav
# wavs/common_voice_eo_18012393.wav
# wavs/common_voice_eo_19868683.wav
# wavs/common_voice_eo_20597936.wav
# wavs/common_voice_eo_20908250.wav
# wavs/common_voice_eo_17937172.wav
# wavs/common_voice_eo_19711880.wav
# wavs/common_voice_eo_19275820.wav
# wavs/common_voice_eo_21015159.wav
# wavs/common_voice_eo_18511243.wav
# wavs/common_voice_eo_19787600.wav
# wavs/common_voice_eo_19878098.wav
# wavs/common_voice_eo_20425155.wav
# wavs/common_voice_eo_20532269.wav
# wavs/common_voice_eo_17908430.wav
# wavs/common_voice_eo_17908627.wav
# wavs/common_voice_eo_19827196.wav
# wavs/common_voice_eo_21099352.wav
# wavs/common_voice_eo_19853830.wav
# wavs/common_voice_eo_20816876.wav
# wavs/common_voice_eo_19780561.wav
# wavs/common_voice_eo_18592103.wav
# wavs/common_voice_eo_18668239.wav
# wavs/common_voice_eo_20461564.wav
# wavs/common_voice_eo_20490346.wav
# wavs/common_voice_eo_20210791.wav
# wavs/common_voice_eo_20532278.wav
# wavs/common_voice_eo_20423617.wav
# wavs/common_voice_eo_19498575.wav
# wavs/common_voice_eo_21427288.wav
# wavs/common_voice_eo_20466994.wav
# wavs/common_voice_eo_21140840.wav
# wavs/common_voice_eo_20584262.wav
# wavs/common_voice_eo_19355494.wav
# wavs/common_voice_eo_18592182.wav
# wavs/common_voice_eo_19316697.wav
# wavs/common_voice_eo_18455441.wav
# wavs/common_voice_eo_20470086.wav
# wavs/common_voice_eo_19309049.wav
# wavs/common_voice_eo_18591832.wav
# wavs/common_voice_eo_20809518.wav
# wavs/common_voice_eo_18668105.wav
# wavs/common_voice_eo_21223727.wav
# wavs/common_voice_eo_20539516.wav
# wavs/common_voice_eo_17899336.wav
# wavs/common_voice_eo_20818273.wav
# wavs/common_voice_eo_18588136.wav
# wavs/common_voice_eo_19087937.wav
# wavs/common_voice_eo_17911943.wav
# wavs/common_voice_eo_20425655.wav
# wavs/common_voice_eo_20842662.wav
# wavs/common_voice_eo_18674468.wav
# wavs/common_voice_eo_19859411.wav
# wavs/common_voice_eo_20961964.wav
# wavs/common_voice_eo_20649953.wav
# wavs/common_voice_eo_21304054.wav
# wavs/common_voice_eo_21358953.wav
# wavs/common_voice_eo_20637566.wav
# wavs/common_voice_eo_20817955.wav
# wavs/common_voice_eo_20434447.wav
# wavs/common_voice_eo_20341811.wav
# wavs/common_voice_eo_20469059.wav
# wavs/common_voice_eo_19777846.wav
# wavs/common_voice_eo_19867114.wav
# wavs/common_voice_eo_20483646.wav
# wavs/common_voice_eo_18997123.wav
# wavs/common_voice_eo_20575699.wav
# wavs/common_voice_eo_21060961.wav
# wavs/common_voice_eo_20201783.wav
# wavs/common_voice_eo_19543462.wav
# wavs/common_voice_eo_18545565.wav
# wavs/common_voice_eo_20921265.wav
# wavs/common_voice_eo_20461575.wav
# wavs/common_voice_eo_20016521.wav
# wavs/common_voice_eo_20731496.wav
# wavs/common_voice_eo_19275822.wav
# wavs/common_voice_eo_18153801.wav
# wavs/common_voice_eo_21245111.wav
# wavs/common_voice_eo_19397353.wav
# wavs/common_voice_eo_19498577.wav
# wavs/common_voice_eo_20504875.wav
# wavs/common_voice_eo_21486516.wav
# wavs/common_voice_eo_18746495.wav
# wavs/common_voice_eo_20483101.wav
# wavs/common_voice_eo_18668086.wav
# wavs/common_voice_eo_19780643.wav
# wavs/common_voice_eo_20845089.wav
# wavs/common_voice_eo_20319319.wav
# wavs/common_voice_eo_18492301.wav
# wavs/common_voice_eo_21487387.wav
# wavs/common_voice_eo_20540384.wav
# wavs/common_voice_eo_17898879.wav
# wavs/common_voice_eo_19309084.wav
# wavs/common_voice_eo_19787417.wav
# wavs/common_voice_eo_21512598.wav
# wavs/common_voice_eo_20502557.wav
# wavs/common_voice_eo_21234845.wav
# wavs/common_voice_eo_19128052.wav
# wavs/common_voice_eo_18420170.wav
# wavs/common_voice_eo_19094670.wav
# wavs/common_voice_eo_20722347.wav
# wavs/common_voice_eo_18343449.wav
# wavs/common_voice_eo_20515755.wav
# wavs/common_voice_eo_20342024.wav
# wavs/common_voice_eo_20680189.wav
# wavs/common_voice_eo_20490628.wav
# wavs/common_voice_eo_21240457.wav
# wavs/common_voice_eo_18567077.wav
# wavs/common_voice_eo_19802147.wav
# wavs/common_voice_eo_20602051.wav
# wavs/common_voice_eo_20486743.wav
# wavs/common_voice_eo_20823130.wav
# wavs/common_voice_eo_20835494.wav
# wavs/common_voice_eo_20511780.wav
# wavs/common_voice_eo_18607374.wav
# wavs/common_voice_eo_20973055.wav
# wavs/common_voice_eo_18584944.wav
# wavs/common_voice_eo_20473596.wav
# wavs/common_voice_eo_18433752.wav
# wavs/common_voice_eo_19788558.wav
# wavs/common_voice_eo_18498315.wav
# wavs/common_voice_eo_21061014.wav
# wavs/common_voice_eo_21060984.wav
# wavs/common_voice_eo_20227497.wav
# wavs/common_voice_eo_18433766.wav
# wavs/common_voice_eo_20719555.wav
# wavs/common_voice_eo_18601672.wav
# wavs/common_voice_eo_20532272.wav
# wavs/common_voice_eo_20532274.wav
# wavs/common_voice_eo_19464780.wav
# wavs/common_voice_eo_18553926.wav
# wavs/common_voice_eo_20506996.wav
# wavs/common_voice_eo_21335199.wav
# wavs/common_voice_eo_20743650.wav
# wavs/common_voice_eo_20442676.wav
# wavs/common_voice_eo_19317516.wav
# wavs/common_voice_eo_17911871.wav
# wavs/common_voice_eo_21123777.wav
# wavs/common_voice_eo_19543745.wav
# wavs/common_voice_eo_17908135.wav
# wavs/common_voice_eo_17937069.wav
# wavs/common_voice_eo_19782128.wav
# wavs/common_voice_eo_20920863.wav
# wavs/common_voice_eo_20816826.wav
# wavs/common_voice_eo_19450510.wav
# wavs/common_voice_eo_20688500.wav
# wavs/common_voice_eo_20197931.wav
# wavs/common_voice_eo_19820726.wav
# wavs/common_voice_eo_20592763.wav
# wavs/common_voice_eo_19845117.wav
# wavs/common_voice_eo_19504812.wav
# wavs/common_voice_eo_19805331.wav
# wavs/common_voice_eo_20753857.wav
# wavs/common_voice_eo_21236517.wav
# wavs/common_voice_eo_20448318.wav
# wavs/common_voice_eo_17937162.wav
# wavs/common_voice_eo_17975311.wav
# wavs/common_voice_eo_20188991.wav
# wavs/common_voice_eo_18567164.wav
# wavs/common_voice_eo_20873948.wav
# wavs/common_voice_eo_20091986.wav
# wavs/common_voice_eo_19543526.wav
# wavs/common_voice_eo_20489907.wav
# wavs/common_voice_eo_21272615.wav
# wavs/common_voice_eo_17898667.wav
# wavs/common_voice_eo_17945118.wav
# wavs/common_voice_eo_19854393.wav
# wavs/common_voice_eo_19039435.wav
# wavs/common_voice_eo_19336878.wav
# wavs/common_voice_eo_20962422.wav
# wavs/common_voice_eo_19355756.wav
# wavs/common_voice_eo_20842652.wav
# wavs/common_voice_eo_18746471.wav
# wavs/common_voice_eo_21448302.wav
# wavs/common_voice_eo_20717360.wav
# wavs/common_voice_eo_17904874.wav
# wavs/common_voice_eo_20105688.wav
# wavs/common_voice_eo_20472696.wav
# wavs/common_voice_eo_19311982.wav
# wavs/common_voice_eo_17898902.wav
# wavs/common_voice_eo_19538556.wav
# wavs/common_voice_eo_20684197.wav
# wavs/common_voice_eo_19657576.wav
# wavs/common_voice_eo_19820609.wav
# wavs/common_voice_eo_20313717.wav
# wavs/common_voice_eo_19776655.wav
# wavs/common_voice_eo_18446726.wav
# wavs/common_voice_eo_19827127.wav
# wavs/common_voice_eo_19310586.wav
# wavs/common_voice_eo_17918886.wav
# wavs/common_voice_eo_20237423.wav
# wavs/common_voice_eo_21125029.wav
# wavs/common_voice_eo_18674462.wav
# wavs/common_voice_eo_20905009.wav
# wavs/common_voice_eo_17904364.wav
# wavs/common_voice_eo_20423914.wav
# wavs/common_voice_eo_21201314.wav
# wavs/common_voice_eo_18005627.wav
# wavs/common_voice_eo_20980976.wav
# wavs/common_voice_eo_17908434.wav
# wavs/common_voice_eo_19422497.wav
# wavs/common_voice_eo_17899629.wav
# wavs/common_voice_eo_19538534.wav

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
#
# OLD: We will use the `MrDragonFox/Elise`, which is designed for training TTS models. Ensure that your dataset follows the required format: **text, audio** for single-speaker models or **source, text, audio** for multi-speaker models. You can modify this section to accommodate your own dataset, but maintaining the correct structure is essential for optimal training.

# %%
##### OLD #####
# from datasets import load_dataset
# dataset = load_dataset("MrDragonFox/Elise", split = "train")

# %% [markdown]
# Load Mozilla Common Voice Dataset from .csv instead

# %%
import pandas as pd
import os
from datasets import load_dataset, Audio

# --- Configuration ---
# The name of your input CSV file (pipe-separated).
# Make sure this file is in the same directory as this script.
csv_filename = '/content/drive/MyDrive/Coding/TTS/metadata_full.csv'

# The desired name for your output Parquet file.
output_filename = 'esperanto_tts_dataset.parquet'

# The absolute path to the folder containing your 'wavs' directory.
# For Google Colab, this is typically '/content/'. Set to '' if not needed.
base_path = '/content/'

# --- Script ---

# 1. Check if the input file exists before proceeding.
if not os.path.exists(csv_filename):
    print(f"Error: The file '{csv_filename}' was not found.")
    print("Please make sure your CSV file is in the same folder as this script and the name is correct.")
else:
    try:
        # 2. Read the pipe-separated CSV file into a Pandas DataFrame.
        #    - `sep='|'` tells pandas to use the pipe character as the delimiter.
        #    - `header=0` specifies that the first row of the CSV is the header.
        print(f"Reading data from '{csv_filename}'...")
        df = pd.read_csv(csv_filename, sep='|', header=0)

        # Rename the 'audio_file' column to 'audio' to match the target schema.
        if 'audio_file' in df.columns:
            df.rename(columns={'audio_file': 'audio'}, inplace=True)

        # Prepend the base path to the audio file paths if one is provided.
        # This fixes pathing issues in environments like Google Colab.
        if base_path:
            print(f"Prepending '{base_path}' to all audio file paths...")
            df['audio'] = df['audio'].apply(lambda path: os.path.join(base_path, path))

        # 3. (Optional but Recommended) Verify the first few rows of the DataFrame.
        #    This helps confirm that the data was loaded and paths were updated correctly.
        print("\n--- Data Preview (First 5 Rows) ---")
        display(df.head())

        # 4. (Optional but Recommended) Check the schema and data types.
        #    This shows the structure of your table.
        print("\n--- DataFrame Info ---")
        df.info()

        # 5. Save the DataFrame to a Parquet file.
        #    - `engine='pyarrow'` is the standard engine for writing Parquet files.
        #    - `index=False` prevents pandas from writing the DataFrame index as a column.
        print(f"\nWriting data to '{output_filename}'...")
        df.to_parquet(output_filename, engine='pyarrow', index=False)

        print(f"\n✅ Success! Your Parquet file '{output_filename}' has been created.")

        # --- Verification Step ---
        # This section compares your dataset's schema with the original Hugging Face dataset.
        print("\n--- Verifying Schema Against MrDragonFox/Elise ---")
        try:
            print("Loading original dataset from Hugging Face (this may take a moment)...")
            # Load the reference dataset from Hugging Face
            hf_dataset = load_dataset("MrDragonFox/Elise", split="train")

            # Convert both the local and remote datasets to pandas DataFrames for easy comparison
            local_df = pd.read_parquet(output_filename)
            hf_df = hf_dataset.to_pandas()

            # Compare column names
            local_cols = sorted(list(local_df.columns))
            hf_cols = sorted(list(hf_df.columns))

            print(f"\nYour file's columns: {local_cols}")
            print(f"Target dataset's columns: {hf_cols}")

            if local_cols == hf_cols:
                print("✅ Column names match.")

                # Compare data types (dtypes)
                if local_df.dtypes.equals(hf_df.dtypes):
                    print("✅ Data types match.")
                    print("\n🎉 Schema verification successful! Your dataset structure matches the target.")
                else:
                    print("⚠️ Warning: Data types do not match exactly.")
                    print("This might be okay if they are compatible.")
                    print("\nYour dtypes:\n", local_df.dtypes)
                    print("\nTarget dtypes:\n", hf_df.dtypes)
            else:
                print("❌ Error: Column names DO NOT match!")
                print(f"Columns in your file but not in target: {set(local_cols) - set(hf_cols)}")
                print(f"Columns in target but not in your file: {set(hf_cols) - set(local_cols)}")

            # --- Final Loading Step ---
            print("\n--- Loading Your Local Parquet as a Hugging Face Dataset ---")

            # Load your local parquet file into a Dataset object.
            dataset = load_dataset('parquet', data_files={'train': output_filename}, split='train')

            # Cast the 'audio' column to the 'Audio' feature.
            dataset = dataset.cast_column("audio", Audio(sampling_rate=22050))

            print("\n✅ Your local dataset is now loaded and ready for training!")
            print("Preview of the first item (notice the 'audio' field is now processed):")
            print(dataset[0])


        except ImportError:
            print("\nSkipping schema verification. To enable this check, please install the 'datasets' library:")
            print("pip install datasets")
        except Exception as e:
            print(f"\nAn error occurred during schema verification: {e}")

    except Exception as e:
        print(f"\nAn error occurred: {e}")
        print("Please check that your CSV file is formatted correctly (filepath|transcription).")
# Out:
# Reading data from '/content/drive/MyDrive/Coding/TTS/metadata_full.csv'...
# Prepending '/content/' to all audio file paths...
#
# --- Data Preview (First 5 Rows) ---
#                                         audio  \
# 0  /content/wavs/common_voice_eo_20917469.wav
# 1  /content/wavs/common_voice_eo_20560866.wav
# 2  /content/wavs/common_voice_eo_20260609.wav
# 3  /content/wavs/common_voice_eo_17899644.wav
# 4  /content/wavs/common_voice_eo_20105659.wav
#
#                                                 text
# 0  Iom post iom tiu tamen akiris la respekton de ...
# 1                Dumtempe li edziĝis kaj iĝis patro.
# 2  Numero unua: Pipo, tabakujo kaj alumetujo; por...
# 3                         Ameno diablon ne forpelas.
# 4                               Ĝi estis vaporboato.
# --- DataFrame Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7478 entries, 0 to 7477
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   audio   7478 non-null   object
#  1   text    7478 non-null   object
# dtypes: object(2)
# memory usage: 117.0+ KB
#
# Writing data to 'esperanto_tts_dataset.parquet'...
#
# ✅ Success! Your Parquet file 'esperanto_tts_dataset.parquet' has been created.
#
# --- Verifying Schema Against MrDragonFox/Elise ---
# Loading original dataset from Hugging Face (this may take a moment)...
#
# Your file's columns: ['audio', 'text']
# Target dataset's columns: ['audio', 'text']
# ✅ Column names match.
# ✅ Data types match.
#
# 🎉 Schema verification successful! Your dataset structure matches the target.
#
# --- Loading Your Local Parquet as a Hugging Face Dataset ---
# Generating train split: 0 examples [00:00, ? examples/s]
# ✅ Your local dataset is now loaded and ready for training!
# Preview of the first item (notice the 'audio' field is now processed):
# {'audio': {'path': '/content/wavs/common_voice_eo_20917469.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -3.05175781e-05, -3.05175781e-05,  0.00000000e+00]), 'sampling_rate': 22050}, 'text': 'Iom post iom tiu tamen akiris la respekton de la kapitano.'}

# %%
#@title Tokenization Function

import locale
import torchaudio.transforms as T
import os
import torch
from snac import SNAC
locale.getpreferredencoding = lambda: "UTF-8"
# ds_sample_rate = dataset[0]["audio"]["sampling_rate"] # Removed as it will be available after casting in the previous cell

snac_model = SNAC.from_pretrained("hubertsiuzdak/snac_24khz")
snac_model = snac_model.to("cuda")
def tokenise_audio(waveform):
  waveform = torch.from_numpy(waveform).unsqueeze(0)
  waveform = waveform.to(dtype=torch.float32)
  resample_transform = T.Resample(orig_freq=dataset[0]["audio"]["sampling_rate"], new_freq=24000) # Access sampling rate directly from dataset
  waveform = resample_transform(waveform)

  waveform = waveform.unsqueeze(0).to("cuda")

  #generate the codes from snac
  with torch.inference_mode():
    codes = snac_model.encode(waveform)

  all_codes = []
  for i in range(codes[0].shape[1]):
    all_codes.append(codes[0][0][i].item()+128266)
    all_codes.append(codes[1][0][2*i].item()+128266+4096)
    all_codes.append(codes[2][0][4*i].item()+128266+(2*4096))
    all_codes.append(codes[2][0][(4*i)+1].item()+128266+(3*4096))
    all_codes.append(codes[1][0][(2*i)+1].item()+128266+(4*4096))
    all_codes.append(codes[2][0][(4*i)+2].item()+128266+(5*4096))
    all_codes.append(codes[2][0][(4*i)+3].item()+128266+(6*4096))


  return all_codes

def add_codes(example):
    # Always initialize codes_list to None
    codes_list = None

    try:
        answer_audio = example.get("audio")
        # If there's a valid audio array, tokenise it
        if answer_audio and "array" in answer_audio:
            audio_array = answer_audio["array"]
            codes_list = tokenise_audio(audio_array)
    except Exception as e:
        print(f"Skipping row due to error: {e}")
        # Keep codes_list as None if we fail
    example["codes_list"] = codes_list

    return example

dataset = dataset.map(add_codes, remove_columns=["audio"])

tokeniser_length = 128256
start_of_text = 128000
end_of_text = 128009

start_of_speech = tokeniser_length + 1
end_of_speech = tokeniser_length + 2

start_of_human = tokeniser_length + 3
end_of_human = tokeniser_length + 4

start_of_ai = tokeniser_length + 5
end_of_ai =  tokeniser_length + 6
pad_token = tokeniser_length + 7

audio_tokens_start = tokeniser_length + 10

dataset = dataset.filter(lambda x: x["codes_list"] is not None)
dataset = dataset.filter(lambda x: len(x["codes_list"]) > 0)

def remove_duplicate_frames(example):
    vals = example["codes_list"]
    if len(vals) % 7 != 0:
        raise ValueError("Input list length must be divisible by 7")

    result = vals[:7]

    removed_frames = 0

    for i in range(7, len(vals), 7):
        current_first = vals[i]
        previous_first = result[-7]

        if current_first != previous_first:
            result.extend(vals[i:i+7])
        else:
            removed_frames += 1

    example["codes_list"] = result

    return example

dataset = dataset.map(remove_duplicate_frames)

tok_info = '''*** HERE you can modify the text prompt
If you are training a multi-speaker model (e.g., canopylabs/orpheus-3b-0.1-ft),
ensure that the dataset includes a "source" field and format the input accordingly:
- Single-speaker: f"{example['text']}"
- Multi-speaker: f"{example['source']}: {example['text']}"
'''
print(tok_info)

def create_input_ids(example):
    # Determine whether to include the source field
    text_prompt = f"{example['source']}: {example['text']}" if "source" in example else example["text"]

    text_ids = tokenizer.encode(text_prompt, add_special_tokens=True)
    text_ids.append(end_of_text)

    example["text_tokens"] = text_ids
    input_ids = (
        [start_of_human]
        + example["text_tokens"]
        + [end_of_human]
        + [start_of_ai]
        + [start_of_speech]
        + example["codes_list"]
        + [end_of_speech]
        + [end_of_ai]
    )
    example["input_ids"] = input_ids
    example["labels"] = input_ids
    example["attention_mask"] = [1] * len(input_ids)

    return example


dataset = dataset.map(create_input_ids, remove_columns=["text", "codes_list"])
columns_to_keep = ["input_ids", "labels", "attention_mask"]
columns_to_remove = [col for col in dataset.column_names if col not in columns_to_keep]

dataset = dataset.remove_columns(columns_to_remove)
# Out:
# Parameter 'function'=<function add_codes at 0x7c8c69222160> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# WARNING:datasets.fingerprint:Parameter 'function'=<function add_codes at 0x7c8c69222160> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# Map:   0%|          | 0/7478 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/7478 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/7478 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7478 [00:00<?, ? examples/s]
# *** HERE you can modify the text prompt
# If you are training a multi-speaker model (e.g., canopylabs/orpheus-3b-0.1-ft),
# ensure that the dataset includes a "source" field and format the input accordingly:
# - Single-speaker: f"{example['text']}"
# - Multi-speaker: f"{example['source']}: {example['text']}"
# Map:   0%|          | 0/7478 [00:00<?, ? examples/s]

# %% [markdown]
# RAM Clear

# %%
# import torch

# torch.cuda.empty_cache()

# import gc

# # Delete large variables you are no longer using
# del model
# del trainer
# del dataset

# # Run garbage collection
# gc.collect()
# Out:
# 2396

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")

import re

def get_system_ram_usage():
    try:
        # Read memory information from /proc/meminfo
        with open('/proc/meminfo', 'r') as f:
            meminfo = f.read()

        # Use regular expressions to find the relevant values
        mem_total_kb = int(re.search(r'MemTotal:\s+(\d+)', meminfo).group(1))
        mem_available_kb = int(re.search(r'MemAvailable:\s+(\d+)', meminfo).group(1))

        # Calculate used memory
        mem_used_kb = mem_total_kb - mem_available_kb

        # Convert kilobytes to gigabytes
        total_ram_gb = round(mem_total_kb / (1024**2), 2)
        used_ram_gb = round(mem_used_kb / (1024**2), 2)
        free_ram_gb = round(mem_available_kb / (1024**2), 2)

        # Calculate percentage
        percent_used = round((mem_used_kb / mem_total_kb) * 100, 2)

        print("System RAM Usage (from /proc/meminfo):")
        print(f"Total: {total_ram_gb} GB")
        print(f"Used: {used_ram_gb} GB")
        print(f"Free (Available): {free_ram_gb} GB")
        print(f"Percentage Used: {percent_used}%")

    except FileNotFoundError:
        print("Could not find /proc/meminfo. This method only works on Linux-based systems.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Run the function to get the stats
get_system_ram_usage()
# Out:
# GPU = NVIDIA A100-SXM4-40GB. Max memory = 39.557 GB.
# 25.645 GB of memory reserved.
# System RAM Usage (from /proc/meminfo):
# Total: 83.48 GB
# Used: 76.35 GB
# Free (Available): 7.13 GB
# Percentage Used: 91.46%

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface  `Trainer`! More docs here: [Transformers docs](https://huggingface.co/docs/transformers/main_classes/trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`.
#
# **Note:** Using a per_device_train_batch_size >1 may lead to errors if multi-GPU setup to avoid issues, ensure CUDA_VISIBLE_DEVICES is set to a single GPU (e.g., CUDA_VISIBLE_DEVICES=0).

# %%
from transformers import TrainingArguments,Trainer,DataCollatorForSeq2Seq
tokenizer.pad_token_id = 128263
data_collator = DataCollatorForSeq2Seq(
  tokenizer,
  pad_to_multiple_of = 8,
  padding = True,
)

trainer = Trainer(
    model = model,
    train_dataset = dataset,
    args = TrainingArguments(
        per_device_train_batch_size = 96,
        gradient_accumulation_steps = 2,
        warmup_steps = 100,
        num_train_epochs = 1, # Set this for 1 full training run.
        # max_steps = 5,
        learning_rate = 2e-4,
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none", # Use this for WandB etc
        save_strategy="steps", # Add this to save checkpoints
        save_steps=100, # Add this to specify how often to save checkpoints
        save_total_limit=2, # Optional: Limit the number of checkpoints to save
    ),
    data_collator=data_collator,
)
# To resume from a checkpoint, uncomment the line below and replace "path/to/checkpoint"
# with the actual path to your checkpoint directory.
# trainer_stats = trainer.train(resume_from_checkpoint="path/to/checkpoint")
trainer_stats = trainer.train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1914515718.py in <cell line: 0>()
#       8
#       9 trainer = Trainer(
# ---> 10     model = model,
#      11     train_dataset = dataset,
#      12     args = TrainingArguments(
#
# NameError: name 'model' is not defined

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the prompts

# %%
# prompts = [
#     "Hey there my name is Elise, <giggles> and I'm a speech generation model that can sound like a person.",
# ]
prompts = [
    # "Ĉi tiu esprimo povus esti dirata ankaŭ male: Diris Zamenhof al Klara"
    "Ĉiu lingvo daŭre ŝanĝiĝas, dum ĝi estas parolata!"
]
lang = "eo"
dataset_length = "10h"
steps = "60st"
epochs = ""

chosen_voice = None # None for single-speaker

# %%
#@title Run Inference


FastLanguageModel.for_inference(model) # Enable native 2x faster inference

# Moving snac_model cuda to cpu
snac_model.to("cpu")

prompts_ = [(f"{chosen_voice}: " + p) if chosen_voice else p for p in prompts]

all_input_ids = []

for prompt in prompts_:
  input_ids = tokenizer(prompt, return_tensors="pt").input_ids
  all_input_ids.append(input_ids)

start_token = torch.tensor([[ 128259]], dtype=torch.int64) # Start of human
end_tokens = torch.tensor([[128009, 128260]], dtype=torch.int64) # End of text, End of human

all_modified_input_ids = []
for input_ids in all_input_ids:
  modified_input_ids = torch.cat([start_token, input_ids, end_tokens], dim=1) # SOH SOT Text EOT EOH
  all_modified_input_ids.append(modified_input_ids)

all_padded_tensors = []
all_attention_masks = []
max_length = max([modified_input_ids.shape[1] for modified_input_ids in all_modified_input_ids])
for modified_input_ids in all_modified_input_ids:
  padding = max_length - modified_input_ids.shape[1]
  padded_tensor = torch.cat([torch.full((1, padding), 128263, dtype=torch.int64), modified_input_ids], dim=1)
  attention_mask = torch.cat([torch.zeros((1, padding), dtype=torch.int64), torch.ones((1, modified_input_ids.shape[1]), dtype=torch.int64)], dim=1)
  all_padded_tensors.append(padded_tensor)
  all_attention_masks.append(attention_mask)

all_padded_tensors = torch.cat(all_padded_tensors, dim=0)
all_attention_masks = torch.cat(all_attention_masks, dim=0)

input_ids = all_padded_tensors.to("cuda")
attention_mask = all_attention_masks.to("cuda")
generated_ids = model.generate(
      input_ids=input_ids,
      attention_mask=attention_mask,
      max_new_tokens=1200,
      do_sample=True,
      temperature=0.6,
      top_p=0.95,
      repetition_penalty=1.1,
      num_return_sequences=1,
      eos_token_id=128258,
     use_cache = True
  )
token_to_find = 128257
token_to_remove = 128258

token_indices = (generated_ids == token_to_find).nonzero(as_tuple=True)

if len(token_indices[1]) > 0:
    last_occurrence_idx = token_indices[1][-1].item()
    cropped_tensor = generated_ids[:, last_occurrence_idx+1:]
else:
    cropped_tensor = generated_ids

mask = cropped_tensor != token_to_remove

processed_rows = []

for row in cropped_tensor:
    masked_row = row[row != token_to_remove]
    processed_rows.append(masked_row)

code_lists = []

for row in processed_rows:
    row_length = row.size(0)
    new_length = (row_length // 7) * 7
    trimmed_row = row[:new_length]
    trimmed_row = [t - 128266 for t in trimmed_row]
    code_lists.append(trimmed_row)


def redistribute_codes(code_list):
  layer_1 = []
  layer_2 = []
  layer_3 = []
  for i in range((len(code_list)+1)//7):
    layer_1.append(code_list[7*i])
    layer_2.append(code_list[7*i+1]-4096)
    layer_3.append(code_list[7*i+2]-(2*4096))
    layer_3.append(code_list[7*i+3]-(3*4096))
    layer_2.append(code_list[7*i+4]-(4*4096))
    layer_3.append(code_list[7*i+5]-(5*4096))
    layer_3.append(code_list[7*i+6]-(6*4096))
  codes = [torch.tensor(layer_1).unsqueeze(0),
         torch.tensor(layer_2).unsqueeze(0),
         torch.tensor(layer_3).unsqueeze(0)]

  # codes = [c.to("cuda") for c in codes]
  audio_hat = snac_model.decode(codes)
  return audio_hat

my_samples = []
for code_list in code_lists:
  samples = redistribute_codes(code_list)
  my_samples.append(samples)

import os
from scipy.io.wavfile import write as write_wav
from IPython.display import display, Audio
import re

# Specify the path to save your audio files
output_path = "generated_audio"

# Create the directory if it doesn't already exist
os.makedirs(output_path, exist_ok=True)

# Define the sample rate
sample_rate = 24000

if len(prompts) != len(my_samples):
  raise Exception("Number of prompts and samples do not match")
else:
  for i in range(len(my_samples)):
    prompt_text = prompts[i]
    samples = my_samples[i]

    print(f"Processing prompt: '{prompt_text}'")

    # Prepare the audio data
    audio_data = samples.detach().squeeze().to("cpu").numpy()

    # --- NEW: Sanitize the prompt to create a valid filename ---
    # This takes the first 5 words, joins them with underscores, and removes invalid characters
    safe_prompt_text = "_".join(prompt_text.split())
    safe_prompt_text = re.sub(r'[\\/*?:"<>|]', "", safe_prompt_text)

    # --- NEW: Construct the filename using your variables ---
    filename = f"{safe_prompt_text}_orpheus_{lang}_{dataset_length}_{steps}.wav"
    file_path = os.path.join(output_path, filename)

    # Save the audio data to the specified path
    write_wav(file_path, sample_rate, audio_data)
    print(f"✅ Audio saved to: {file_path}")

    # You can still display the audio in the notebook as before
    display(Audio(audio_data, rate=sample_rate))
    print("-" * 30)

# Clean up to save RAM
del my_samples, samples, audio_data

# %%
# Import libraries for saving the audio file
import os
from scipy.io.wavfile import write as write_wav
from IPython.display import display, Audio

# --- NEW: Specify the path to save your audio files ---
output_path = "generated_audio" # You can change "generated_audio" to any folder name

# --- NEW: Create the directory if it doesn't already exist ---
os.makedirs(output_path, exist_ok=True)

# Define the sample rate
sample_rate = 24000

if len(prompts) != len(my_samples):
  raise Exception("Number of prompts and samples do not match")
else:
  for i in range(len(my_samples)):
    prompt_text = prompts[i]
    samples = my_samples[i]

    print(f"Processing prompt: '{prompt_text}'")

    # Prepare the audio data
    audio_data = samples.detach().squeeze().to("cpu").numpy()

    # --- NEW: Define the full file path for the output WAV file ---
    # We'll name the file based on its index, e.g., "output_0.wav"
    file_path = os.path.join(output_path, f"output_{i}.wav")

    # --- NEW: Save the audio data to the specified path ---
    write_wav(file_path, sample_rate, audio_data)
    print(f"✅ Audio saved to: {file_path}")

    # You can still display the audio in the notebook as before
    display(Audio(audio_data, rate=sample_rate))
    print("-" * 30) # Adds a separator for clarity

# Clean up to save RAM
del my_samples, samples, audio_data

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("lora_model")  # Local saving
tokenizer.save_pretrained("lora_model")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving

# %% [markdown]
# ### Saving to float16
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False:
    model.save_pretrained("model")
    tokenizer.save_pretrained("model")
if False:
    model.push_to_hub("hf/model", token = "")
    tokenizer.push_to_hub("hf/model", token = "")

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
